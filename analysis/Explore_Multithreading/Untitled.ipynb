# %%
using Base.Threads

# %%
Threads.nthreads()
# Out:
# 12

# %%
pwd()
# Out:
# "/home/xyu/github/BulkLMM.jl"

# %%
cd("..")

# %%
include("../test/BXDdata_for_test.jl");

# %%
include("../src/parallel_helpers.jl");

# %%
include("../test/testHelper.jl");

# %%
function scan_perms_threads(y::Array{Float64,2}, g::Array{Float64,2}, K::Array{Float64,2};
              nperms::Int64 = 1024, rndseed::Int64 = 0, 
              reml::Bool = false, original::Bool = true)

    # check the number of traits as this function only works for permutation testing of univariate trait
    if(size(y, 2) != 1)
        error("Can only handle one trait.")
    end

    # n - the sample size
    # p - the number of markers
    (n, p) = size(g)

    # make intercept
    intercept = ones(n, 1)

    # rotate data so errors are uncorrelated
    (y0, X0, lambda0) = rotateData(y, [intercept g], K)


    ## Note: estimate once the variance components from the null model and use for all marker scans
    # fit lmm

    # X0_intercept = @view X0[:, 1] # to compare
    vc = fitlmm(y0, reshape(X0[:, 1], :, 1), lambda0; reml = reml) # vc.b is estimated through weighted least square
    r0 = y0 - X0[:, 1]*vc.b

    # weights proportional to the variances
    sqrtw = sqrt.(makeweights(vc.h2, lambda0))

    # compared runtime of the following with "wls(X0[:, 2:end], X0[:, 1], wts)" ?
    # rescale by weights; now these have the same mean/variance and are independent
    rowMultiply!(r0, sqrtw);
    rowMultiply!(X0, sqrtw);

    
    # after re-weighting X, calling resid on re-weighted X is the same as doing wls on the X after rotation.
    X00 = resid(X0[:, 2:end], reshape(X0[:, 1], :, 1)) # consider not using sub-array, consider @view; in-place changes

    ## random permutations; the first column is the original trait (after transformation)
    rng = MersenneTwister(rndseed);
    ## permute r0 (which is an iid, standard normal distributed N-vector under the null)
    r0perm = shuffleVector(rng, r0[:, 1], nperms; original = original)

    ## Null RSS:
    # By null hypothesis, mean is 0. RSS just becomes the sum of squares of the residuals (r0perm's)
    # (For theoretical derivation of the results, see notebook)
    rss0 = sum(r0perm[:, 1].^2) # a scalar; bc rss0 for every permuted trait is the same under the null (zero mean);
    
    ## make array to hold Alternative RSS's for each permutated trait
    if original
        rss1 = Array{Float64, 2}(undef, nperms+1, p)
    else
        rss1 = Array{Float64, 2}(undef, nperms, p)
    end
    
    ## loop over markers
    Threads.@threads for i = 1:p

        ## alternative rss
        @inbounds rss1[:, i] = rss(r0perm, @view X00[:, i]);
        
    end

    lod = (-n/2)*(log10.(rss1) .- log10(rss0))

    return lod

end
# Out:
# scan_perms_threads (generic function with 1 method)

# %%
function scan_null_threads(y::Array{Float64,2}, g::Array{Float64,2}, K::Array{Float64,2};
                   reml::Bool = false)

    # number of markers
    (n, m) = size(g)
    # make intercept
    intercept = ones(n, 1)
    # rotate data
    (y0, X0, lambda0) = rotateData(y, [intercept g], K)
    # fit null lmm
    out00 = fitlmm(y0, reshape(X0[:, 1], :, 1), lambda0; reml = reml)
    # weights proportional to the variances
    sqrtw = sqrt.(makeweights(out00.h2, lambda0))
    # rescale by weights
    rowMultiply!(y0, sqrtw)
    rowMultiply!(X0, sqrtw)

    # perform genome scan
    out0 = rss(y0, reshape(X0[:, 1], n, 1))
    lod = zeros(m)
    X = zeros(n, 2)
    X[:, 1] = X0[:, 1]
    Threads.@threads for i = 1:m
        X[:, 2] = X0[:, i+1]
        out1 = rss(y0, X)
        lod[i] = (n/2)*(log10(out0[1]) - log10(out1[1]))
    end

    return (out00.sigma2, out00.h2, lod)

end
# Out:
# scan_null_threads (generic function with 1 method)

# %%
tloops_LODs_noperms = scan_null(pheno_y, geno, kinship; reml = false);

# %%
using Profile, POkg

# %%
Pkg.add("ProfileView")
# Out:
# UndefVarError: Pkg not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[79]:1
#  [2] eval
#    @ ./boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1428

# %%
@profile scan_null_threads(pheno_y, geno, kinship; reml = false);

# %%
Profile.print()
# Out:
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#     ╎3     ...mpiler/typeinfer.jl:996; typeinf_ext_toplevel(mi::Core....
#     ╎ 3     ...piler/typeinfer.jl:1000; typeinf_ext_toplevel(interp::...
#     ╎  3     ...piler/typeinfer.jl:967; typeinf_ext(interp::Core.Comp...
#     ╎   3     ...piler/typeinfer.jl:213; typeinf(interp::Core.Compile...
#     ╎    3     ...iler/typeinfer.jl:230; _typeinf(interp::Core.Compil...
#     ╎     3     ...interpretation.jl:2462; typeinf_nocycle(interp::Cor...
#     ╎    ╎ 3     ...nterpretation.jl:2366; typeinf_local(interp::Core...
#     ╎    ╎  3     ...nterpretation.jl:1890; abstract_eval_statement(i...
#     ╎    ╎   3     ...terpretation.jl:1733; abstract_call(interp::Cor...
#     ╎    ╎    3     ...terpretation.jl:1764; abstract_call(interp::Co...
#     ╎    ╎     3     ...terpretation.jl:153; abstract_call_gf_by_type...
#     ╎    ╎    ╎ 3     ...terpretation.jl:641; abstract_call_method(int...
#     ╎    ╎    ╎  3     ...r/typeinfer.jl:877; typeinf_edge(interp::Co...
#     ╎    ╎    ╎   3     ...r/typeinfer.jl:213; typeinf(interp::Core.C...
#     ╎    ╎    ╎    2     .../typeinfer.jl:230; _typeinf(interp::Core....
#     ╎    ╎    ╎     2     ...rpretation.jl:2462; typeinf_nocycle(inter...
#     ╎    ╎    ╎    ╎ 2     ...pretation.jl:2366; typeinf_local(interp...
#     ╎    ╎    ╎    ╎  2     ...pretation.jl:1890; abstract_eval_state...
#     ╎    ╎    ╎    ╎   2     ...retation.jl:1733; abstract_call(inter...
#     ╎    ╎    ╎    ╎    2     ...retation.jl:1764; abstract_call(inte...
#     ╎    ╎    ╎    ╎     2     ...retation.jl:153; abstract_call_gf_b...
#     ╎    ╎    ╎    ╎    ╎ 2     ...retation.jl:641; abstract_call_meth...
#     ╎    ╎    ╎    ╎    ╎  2     ...peinfer.jl:877; typeinf_edge(inte...
#     ╎    ╎    ╎    ╎    ╎   2     ...peinfer.jl:213; typeinf(interp::...
#     ╎    ╎    ╎    ╎    ╎    2     ...einfer.jl:257; _typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎     2     ...timize.jl:504; optimize
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...timize.jl:539; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎  1     ...lining.jl:82; ssa_inlining_pa...
#     ╎    ╎    ╎    ╎    ╎    ╎   1     ...lining.jl:1420; assemble_inline...
#     ╎    ╎    ╎    ╎    ╎    ╎    1     ...lining.jl:1205; analyze_single_...
#     ╎    ╎    ╎    ╎    ╎    ╎     1     ...lining.jl:1288; handle_match!(m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...lining.jl:861; analyze_method!...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...lining.jl:804; resolve_todo(to...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...lining.jl:870; InliningTodo
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...timize.jl:543; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎  1     ...passes.jl:1137; adce_pass!(ir::...
#     ╎    ╎    ╎    ╎    ╎    ╎   1     ...air/ir.jl:1308; iterate(compact...
#     ╎    ╎    ╎    ╎    ╎    ╎    1     ...air/ir.jl:990; process_node!(c...
#    1╎    ╎    ╎    ╎    ╎    ╎     1     ...air/ir.jl:238; getindex
#     ╎    ╎    ╎    1     .../typeinfer.jl:257; _typeinf(interp::Core....
#     ╎    ╎    ╎     1     ...r/optimize.jl:504; optimize
#     ╎    ╎    ╎    ╎ 1     ...r/optimize.jl:541; run_passes(ci::Core.C...
#     ╎    ╎    ╎    ╎  1     .../ssair/ir.jl:1459; compact!
#     ╎    ╎    ╎    ╎   1     ...ssair/ir.jl:1459; compact!(code::Core...
#     ╎    ╎    ╎    ╎    1     ...ssair/ir.jl:614; Core.Compiler.Incre...
#     ╎    ╎    ╎    ╎     1     ...ssair/ir.jl:269; NewNodeStream
#     ╎    ╎    ╎    ╎    ╎ 1     ...ssair/ir.jl:269; NewNodeStream
#     ╎    ╎    ╎    ╎    ╎  1     ...e/array.jl:534; fill
#     ╎    ╎    ╎    ╎    ╎   1     ...e/array.jl:536; fill
#     ╎    ╎    ╎    ╎    ╎    1     ...e/boot.jl:468; Array
#    1╎    ╎    ╎    ╎    ╎     1     ...e/boot.jl:459; Array
#    3╎3     @Base/reduce.jl:0; mapreduce_impl(f::typeof(ident...
#    5╎5     @Base/reduce.jl:248; mapreduce_impl(f::typeof(ident...
#     ╎403   @Base/task.jl:484; (::IJulia.var"#15#18")()
#     ╎ 403   ...ia/src/eventloop.jl:8; eventloop(socket::ZMQ.Socket)
#     ╎  403   @Base/essentials.jl:726; invokelatest
#     ╎   403   @Base/essentials.jl:729; #invokelatest#2
#     ╎    403   ...execute_request.jl:67; execute_request(socket::ZMQ....
#     ╎     403   ...oftGlobalScope.jl:65; softscope_include_string(m::...
#     ╎    ╎ 403   @Base/loading.jl:1428; include_string(mapexpr::ty...
#   74╎    ╎  403   @Base/boot.jl:368; eval
#     ╎    ╎   180   In[10]:1; (::var"#scan_perms_thread...
#     ╎    ╎    1     In[10]:18; scan_perms_threads(y::Mat...
#     ╎    ╎     1     ...M.jl/src/lmm.jl:47; rotateData
#     ╎    ╎    ╎ 1     ...a/src/matmul.jl:148; *
#     ╎    ╎    ╎  1     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎   1     .../src/matmul.jl:425; mul!
#     ╎    ╎    ╎    1     ...src/matmul.jl:378; mul!
#     ╎    ╎    ╎     1     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    1╎    ╎    ╎    ╎ 1     .../src/blas.jl:1514; gemm!(transA::Char, ...
#     ╎    ╎    4     In[10]:38; scan_perms_threads(y::Mat...
#     ╎    ╎     2     ...bstractarray.jl:1241; getindex
#     ╎    ╎    ╎ 2     ...idimensional.jl:875; _getindex
#     ╎    ╎    ╎  2     ...dimensional.jl:889; _unsafe_getindex(::Inde...
#     ╎    ╎    ╎   2     ...dimensional.jl:898; _unsafe_getindex!
#     ╎    ╎    ╎    2     ...e/cartesian.jl:64; macro expansion
#     ╎    ╎    ╎     1     ...imensional.jl:903; macro expansion
#    1╎    ╎    ╎    ╎ 1     @Base/array.jl:966; setindex!
#     ╎    ╎    ╎     1     ...imensional.jl:904; macro expansion
#     ╎    ╎    ╎    ╎ 1     @Base/range.jl:883; iterate
#    1╎    ╎    ╎    ╎  1     ...promotion.jl:477; ==
#     ╎    ╎     2     ...M.jl/src/wls.jl:167; resid
#     ╎    ╎    ╎ 1     ...M.jl/src/wls.jl:172; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  1     ...src/generic.jl:1102; \(A::Matrix{Float64}, ...
#     ╎    ╎    ╎   1     ...rc/diagonal.jl:73; Diagonal
#     ╎    ╎    ╎    1     .../src/dense.jl:249; diag
#     ╎    ╎    ╎     1     .../src/dense.jl:249; diag(A::Matrix{Float6...
#     ╎    ╎    ╎    ╎ 1     .../src/dense.jl:225; diagind
#     ╎    ╎    ╎    ╎  1     ...src/dense.jl:201; diagind
#     ╎    ╎    ╎    ╎   1     @Base/range.jl:138; range##kw
#     ╎    ╎    ╎    ╎    1     @Base/range.jl:138; #range#68
#     ╎    ╎    ╎    ╎     1     @Base/range.jl:159; _range
#     ╎    ╎    ╎    ╎    ╎ 1     @Base/range.jl:207; range_start_step_l...
#     ╎    ╎    ╎    ╎    ╎  1     ...e/range.jl:316; StepRange
#    1╎    ╎    ╎    ╎    ╎   1     ...e/range.jl:321; steprange_last(s...
#     ╎    ╎    ╎ 1     ...M.jl/src/wls.jl:182; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  1     .../src/matmul.jl:148; *
#     ╎    ╎    ╎   1     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎    1     ...src/matmul.jl:161; mul!
#     ╎    ╎    ╎     1     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    1╎    ╎    ╎    ╎ 1     .../src/blas.jl:1514; gemm!(transA::Char, ...
#     ╎    ╎    3     In[10]:43; scan_perms_threads(y::Mat...
#     ╎    ╎     3     ....jl/src/util.jl:152; shuffleVector##kw
#     ╎    ╎    ╎ 3     ....jl/src/util.jl:165; shuffleVector(rng::Merse...
#     ╎    ╎    ╎  3     ...om/src/misc.jl:256; shuffle
#     ╎    ╎    ╎   2     ...tractarray.jl:1152; copymutable
#     ╎    ╎    ╎    1     @Base/array.jl:346; copyto!
#     ╎    ╎    ╎     1     @Base/array.jl:322; copyto!
#     ╎    ╎    ╎    ╎ 1     @Base/array.jl:331; _copyto_impl!(dest::V...
#    1╎    ╎    ╎    ╎  1     @Base/array.jl:289; unsafe_copyto!
#     ╎    ╎    ╎    1     @Base/array.jl:373; similar
#    1╎    ╎    ╎     1     @Base/boot.jl:459; Array
#     ╎    ╎    ╎   1     ...m/src/misc.jl:222; shuffle!(r::MersenneTw...
#     ╎    ╎    ╎    1     ...src/Random.jl:225; rand
#     ╎    ╎    ╎     1     ...src/Random.jl:235; rand
#     ╎    ╎    ╎    ╎ 1     ...src/Random.jl:254; rand
#     ╎    ╎    ╎    ╎  1     ...eneration.jl:128; rand
#     ╎    ╎    ╎    ╎   1     ...rc/Random.jl:254; rand
#     ╎    ╎    ╎    ╎    1     ...src/RNGs.jl:399; rand
#     ╎    ╎    ╎    ╎     1     ...src/RNGs.jl:394; rand_inbounds
#     ╎    ╎    ╎    ╎    ╎ 1     ...src/RNGs.jl:390; rand_inbounds
#     ╎    ╎    ╎    ╎    ╎  1     ...rc/RNGs.jl:191; mt_pop!
#    1╎    ╎    ╎    ╎    ╎   1     @Base/Base.jl:38; getproperty
#     ╎    ╎    8     In[10]:52; scan_perms_threads(y::Mat...
#    8╎    ╎     8     @Base/boot.jl:461; Array
#     ╎    ╎    28    In[10]:58; scan_perms_threads(y::Mat...
#     ╎    ╎     28    ...ngconstructs.jl:89; macro expansion
#     ╎    ╎    ╎ 28    ...ngconstructs.jl:38; threading_run(fun::var"#...
#     ╎    ╎    ╎  28    @Base/task.jl:343; wait
#     ╎    ╎    ╎   28    @Base/task.jl:304; _wait(t::Task)
#     ╎    ╎    ╎    28    .../condition.jl:124; wait(c::Base.GenericCo...
#     ╎    ╎    ╎     28    @Base/task.jl:930; wait()
#   28╎    ╎    ╎    ╎ 28    @Base/task.jl:921; poptask(W::Base.Invas...
#     ╎    ╎    136   In[10]:65; scan_perms_threads(y::Mat...
#     ╎    ╎     19    @Base/arraymath.jl:21; *(A::Float64, B::Matrix{...
#     ╎    ╎    ╎ 19    @Base/broadcast.jl:849; broadcast_preserving_zero_d
#     ╎    ╎    ╎  19    ...e/broadcast.jl:860; materialize
#     ╎    ╎    ╎   19    ...e/broadcast.jl:885; copy
#     ╎    ╎    ╎    19    .../broadcast.jl:913; copyto!
#     ╎    ╎    ╎     19    .../broadcast.jl:960; copyto!
#     ╎    ╎    ╎    ╎ 19    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎  19    ...broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎     4     ...roadcast.jl:670; _broadcast_getinde...
#    4╎    ╎    ╎    ╎    ╎ 4     @Base/float.jl:385; *
#     ╎    ╎    ╎    ╎   15    ...mensional.jl:674; setindex!
#   15╎    ╎    ╎    ╎    15    @Base/array.jl:968; setindex!
#     ╎    ╎     117   @Base/broadcast.jl:860; materialize(bc::Base.Bro...
#     ╎    ╎    ╎ 117   @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  116   ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   116   ...e/broadcast.jl:960; copyto!
#     ╎    ╎    ╎    113   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     113   .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 106   .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  99    ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   99    ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    6     ...roadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎     6     ...roadcast.jl:667; _getindex
#     ╎    ╎    ╎    ╎    ╎ 6     ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎  6     ...nsional.jl:672; getindex
#    6╎    ╎    ╎    ╎    ╎   6     ...e/array.jl:925; getindex
#     ╎    ╎    ╎    ╎    93    ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎     93    ...roadcast.jl:670; _broadcast_getinde...
#    3╎    ╎    ╎    ╎    ╎ 93    ...cial/log.jl:268; log10
#   15╎    ╎    ╎    ╎    ╎  15    ...ial/log.jl:0; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:270; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:271; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:272; _log(x::Float64, ...
#    6╎    ╎    ╎    ╎    ╎  6     ...ial/log.jl:275; _log(x::Float64, ...
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:281; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...entials.jl:438; reinterpret
#     ╎    ╎    ╎    ╎    ╎  4     ...ial/log.jl:283; _log(x::Float64, ...
#    4╎    ╎    ╎    ╎    ╎   4     ...omotion.jl:477; ==
#     ╎    ╎    ╎    ╎    ╎  12    ...ial/log.jl:289; _log(x::Float64, ...
#    6╎    ╎    ╎    ╎    ╎   6     ...entials.jl:438; reinterpret
#    5╎    ╎    ╎    ╎    ╎   5     @Base/int.jl:340; &
#    1╎    ╎    ╎    ╎    ╎   1     @Base/int.jl:365; |
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:292; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:293; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    ╎    ╎    ╎  46    ...ial/log.jl:295; _log(x::Float64, ...
#     ╎    ╎    ╎    ╎    ╎   5     ...ial/log.jl:162; log_proc1
#    5╎    ╎    ╎    ╎    ╎    5     .../float.jl:310; unsafe_trunc
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:165; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     ...e/tuple.jl:29; getindex
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:166; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     .../float.jl:383; +
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:167; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:180; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   10    ...ial/log.jl:181; log_proc1
#   10╎    ╎    ╎    ╎    ╎    10    .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   5     ...ial/log.jl:182; log_proc1
#     ╎    ╎    ╎    ╎    ╎    5     ...rators.jl:591; *
#    5╎    ╎    ╎    ╎    ╎     5     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   18    ...ial/log.jl:189; log_proc1
#    7╎    ╎    ╎    ╎    ╎    7     .../float.jl:383; +
#     ╎    ╎    ╎    ╎    ╎    11    ...tfuncs.jl:422; fma
#   11╎    ╎    ╎    ╎    ╎     11    ...tfuncs.jl:417; fma_llvm
#     ╎    ╎    ╎    ╎  7     ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   7     ...broadcast.jl:670; _broadcast_getindex...
#    7╎    ╎    ╎    ╎    7     @Base/float.jl:384; -
#     ╎    ╎    ╎    ╎ 7     ...imensional.jl:674; setindex!
#    7╎    ╎    ╎    ╎  7     @Base/array.jl:968; setindex!
#     ╎    ╎    ╎    3     @Base/simdloop.jl:78; macro expansion
#    3╎    ╎    ╎     3     @Base/int.jl:87; +
#     ╎    ╎    ╎  1     ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎   1     ...e/broadcast.jl:212; similar
#     ╎    ╎    ╎    1     ...tractarray.jl:840; similar
#     ╎    ╎    ╎     1     ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎ 1     @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎  1     @Base/boot.jl:469; Array
#    1╎    ╎    ╎    ╎   1     @Base/boot.jl:461; Array
#     ╎    ╎   101   In[37]:1; (::var"#scan_perms_thread...
#     ╎    ╎    6     In[37]:18; scan_perms_threads(y::Mat...
#     ╎    ╎     2     ...M.jl/src/lmm.jl:44; rotateData
#     ╎    ╎    ╎ 2     ...ra/src/eigen.jl:235; eigen
#     ╎    ╎    ╎  2     ...a/src/eigen.jl:238; eigen(A::Matrix{Float64...
#     ╎    ╎    ╎   2     ...a/src/eigen.jl:149; eigen!##kw
#     ╎    ╎    ╎    2     .../src/eigen.jl:152; eigen!(A::Matrix{Float...
#     ╎    ╎    ╎     2     ...metriceigen.jl:4; eigen!##kw
#     ╎    ╎    ╎    ╎ 2     ...etriceigen.jl:4; #eigen!#211
#    2╎    ╎    ╎    ╎  2     ...rc/lapack.jl:5102; syevr!(jobz::Char, ...
#     ╎    ╎     4     ...M.jl/src/lmm.jl:47; rotateData
#     ╎    ╎    ╎ 4     ...a/src/matmul.jl:148; *
#     ╎    ╎    ╎  4     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎   4     .../src/matmul.jl:425; mul!
#     ╎    ╎    ╎    4     ...src/matmul.jl:378; mul!
#     ╎    ╎    ╎     4     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    4╎    ╎    ╎    ╎ 4     .../src/blas.jl:1514; gemm!(transA::Char, ...
#     ╎    ╎    1     In[37]:34; scan_perms_threads(y::Mat...
#     ╎    ╎     1     ....jl/src/util.jl:123; rowMultiply!(A::Matrix{F...
#    1╎    ╎    ╎ 1     @Base/float.jl:385; *
#     ╎    ╎    6     In[37]:38; scan_perms_threads(y::Mat...
#     ╎    ╎     6     ...M.jl/src/wls.jl:167; resid
#     ╎    ╎    ╎ 1     ...M.jl/src/wls.jl:172; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  1     .../src/matmul.jl:148; *
#     ╎    ╎    ╎   1     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎    1     ...src/matmul.jl:425; mul!
#     ╎    ╎    ╎     1     ...src/matmul.jl:378; mul!
#     ╎    ╎    ╎    ╎ 1     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    1╎    ╎    ╎    ╎  1     .../src/blas.jl:1514; gemm!(transA::Char,...
#     ╎    ╎    ╎ 4     ...M.jl/src/wls.jl:182; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  4     .../src/matmul.jl:148; *
#     ╎    ╎    ╎   4     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎    4     ...src/matmul.jl:161; mul!
#     ╎    ╎    ╎     4     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    4╎    ╎    ╎    ╎ 4     .../src/blas.jl:1514; gemm!(transA::Char, ...
#     ╎    ╎    ╎ 1     ...M.jl/src/wls.jl:183; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  1     @Base/arraymath.jl:8; -(A::Matrix{Float64}, B:...
#     ╎    ╎    ╎   1     ...e/broadcast.jl:849; broadcast_preserving_z...
#     ╎    ╎    ╎    1     .../broadcast.jl:860; materialize
#     ╎    ╎    ╎     1     .../broadcast.jl:885; copy
#     ╎    ╎    ╎    ╎ 1     .../broadcast.jl:913; copyto!
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:960; copyto!
#     ╎    ╎    ╎    ╎   1     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎     1     ...roadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:670; _broadcast_getind...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    1     In[37]:43; scan_perms_threads(y::Mat...
#     ╎    ╎     1     ....jl/src/util.jl:152; shuffleVector##kw
#     ╎    ╎    ╎ 1     ....jl/src/util.jl:165; shuffleVector(rng::Merse...
#     ╎    ╎    ╎  1     ...stractarray.jl:1344; setindex!
#     ╎    ╎    ╎   1     ...dimensional.jl:930; _setindex!
#     ╎    ╎    ╎    1     ...imensional.jl:941; _unsafe_setindex!(::In...
#     ╎    ╎    ╎     1     .../cartesian.jl:64; macro expansion
#     ╎    ╎    ╎    ╎ 1     ...imensional.jl:947; macro expansion
#     ╎    ╎    ╎    ╎  1     @Base/array.jl:898; iterate
#     ╎    ╎    ╎    ╎   1     @Base/int.jl:991; -
#    1╎    ╎    ╎    ╎    1     @Base/int.jl:86; -
#     ╎    ╎    9     In[37]:58; scan_perms_threads(y::Mat...
#     ╎    ╎     9     ...ngconstructs.jl:89; macro expansion
#     ╎    ╎    ╎ 9     ...ngconstructs.jl:38; threading_run(fun::var"#...
#     ╎    ╎    ╎  9     @Base/task.jl:343; wait
#     ╎    ╎    ╎   9     @Base/task.jl:304; _wait(t::Task)
#     ╎    ╎    ╎    9     .../condition.jl:124; wait(c::Base.GenericCo...
#     ╎    ╎    ╎     9     @Base/task.jl:930; wait()
#    9╎    ╎    ╎    ╎ 9     @Base/task.jl:921; poptask(W::Base.Invas...
#     ╎    ╎    78    In[37]:65; scan_perms_threads(y::Mat...
#     ╎    ╎     10    @Base/arraymath.jl:21; *(A::Float64, B::Matrix{...
#     ╎    ╎    ╎ 10    @Base/broadcast.jl:849; broadcast_preserving_zero_d
#     ╎    ╎    ╎  10    ...e/broadcast.jl:860; materialize
#     ╎    ╎    ╎   10    ...e/broadcast.jl:885; copy
#     ╎    ╎    ╎    10    .../broadcast.jl:913; copyto!
#     ╎    ╎    ╎     10    .../broadcast.jl:960; copyto!
#     ╎    ╎    ╎    ╎ 10    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎  10    ...broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎   5     ...broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎    5     ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎     5     ...roadcast.jl:670; _broadcast_getinde...
#    5╎    ╎    ╎    ╎    ╎ 5     @Base/float.jl:385; *
#     ╎    ╎    ╎    ╎   5     ...mensional.jl:674; setindex!
#    5╎    ╎    ╎    ╎    5     @Base/array.jl:968; setindex!
#     ╎    ╎     68    @Base/broadcast.jl:860; materialize(bc::Base.Bro...
#     ╎    ╎    ╎ 68    @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  68    ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   68    ...e/broadcast.jl:960; copyto!
#     ╎    ╎    ╎    68    @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     68    .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 68    .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  67    ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   67    ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎     1     ...roadcast.jl:667; _getindex
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎  1     ...nsional.jl:672; getindex
#    1╎    ╎    ╎    ╎    ╎   1     ...e/array.jl:925; getindex
#     ╎    ╎    ╎    ╎    66    ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎     66    ...roadcast.jl:670; _broadcast_getinde...
#    5╎    ╎    ╎    ╎    ╎ 66    ...cial/log.jl:268; log10
#   12╎    ╎    ╎    ╎    ╎  12    ...ial/log.jl:0; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:270; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:271; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:272; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:275; _log(x::Float64, ...
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:281; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...entials.jl:438; reinterpret
#     ╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:283; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎   2     ...omotion.jl:477; ==
#     ╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:288; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎   2     @Base/int.jl:86; -
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:289; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...entials.jl:438; reinterpret
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:292; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:293; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    ╎    ╎    ╎  34    ...ial/log.jl:295; _log(x::Float64, ...
#     ╎    ╎    ╎    ╎    ╎   3     ...ial/log.jl:162; log_proc1
#    3╎    ╎    ╎    ╎    ╎    3     .../float.jl:310; unsafe_trunc
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:166; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     .../float.jl:383; +
#     ╎    ╎    ╎    ╎    ╎   5     ...ial/log.jl:181; log_proc1
#    5╎    ╎    ╎    ╎    ╎    5     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:182; log_proc1
#     ╎    ╎    ╎    ╎    ╎    2     ...rators.jl:591; *
#    2╎    ╎    ╎    ╎    ╎     2     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   22    ...ial/log.jl:189; log_proc1
#   12╎    ╎    ╎    ╎    ╎    12    .../float.jl:383; +
#     ╎    ╎    ╎    ╎    ╎    10    ...tfuncs.jl:422; fma
#   10╎    ╎    ╎    ╎    ╎     10    ...tfuncs.jl:417; fma_llvm
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   1     ...broadcast.jl:670; _broadcast_getindex...
#    1╎    ╎    ╎    ╎    1     @Base/float.jl:384; -
#     ╎    ╎   1     In[38]:1; (::var"#scan_null_threads...
#     ╎    ╎    1     In[38]:9; scan_null_threads(y::Matri...
#     ╎    ╎     1     ...M.jl/src/lmm.jl:44; rotateData
#     ╎    ╎    ╎ 1     ...ra/src/eigen.jl:235; eigen
#     ╎    ╎    ╎  1     ...a/src/eigen.jl:238; eigen(A::Matrix{Float64...
#     ╎    ╎    ╎   1     ...a/src/eigen.jl:149; eigen!##kw
#     ╎    ╎    ╎    1     .../src/eigen.jl:152; eigen!(A::Matrix{Float...
#     ╎    ╎    ╎     1     ...metriceigen.jl:4; eigen!##kw
#     ╎    ╎    ╎    ╎ 1     ...etriceigen.jl:4; #eigen!#211
#    1╎    ╎    ╎    ╎  1     ...rc/lapack.jl:5102; syevr!(jobz::Char, ...
#     ╎    ╎   26    In[73]:1; (::var"#scan_null_threads...
#     ╎    ╎    2     In[73]:9; scan_null_threads(y::Matr...
#     ╎    ╎     1     .../src/special.jl:426; hcat
#     ╎    ╎    ╎ 1     ...stractarray.jl:1586; typed_hcat
#     ╎    ╎    ╎  1     ...stractarray.jl:1611; _typed_hcat(#unused#::...
#     ╎    ╎    ╎   1     @Base/array.jl:322; copyto!
#     ╎    ╎    ╎    1     @Base/array.jl:331; _copyto_impl!(dest::Ma...
#    1╎    ╎    ╎     1     @Base/array.jl:289; unsafe_copyto!
#     ╎    ╎     1     ...M.jl/src/lmm.jl:44; rotateData
#     ╎    ╎    ╎ 1     ...ra/src/eigen.jl:235; eigen
#     ╎    ╎    ╎  1     ...a/src/eigen.jl:238; eigen(A::Matrix{Float64...
#     ╎    ╎    ╎   1     ...a/src/eigen.jl:149; eigen!##kw
#     ╎    ╎    ╎    1     .../src/eigen.jl:152; eigen!(A::Matrix{Float...
#     ╎    ╎    ╎     1     ...metriceigen.jl:4; eigen!##kw
#     ╎    ╎    ╎    ╎ 1     ...etriceigen.jl:4; #eigen!#211
#    1╎    ╎    ╎    ╎  1     ...rc/lapack.jl:5102; syevr!(jobz::Char, ...
#     ╎    ╎    1     In[73]:16; scan_null_threads(y::Matr...
#     ╎    ╎     1     ....jl/src/util.jl:123; rowMultiply!(A::Matrix{F...
#    1╎    ╎    ╎ 1     @Base/array.jl:968; setindex!
#     ╎    ╎    23    In[73]:23; scan_null_threads(y::Matr...
#   18╎    ╎     23    ...ngconstructs.jl:89; macro expansion
#     ╎    ╎    ╎ 4     ...er/typeinfer.jl:996; typeinf_ext_toplevel(mi:...
#     ╎    ╎    ╎  4     ...r/typeinfer.jl:1000; typeinf_ext_toplevel(i...
#     ╎    ╎    ╎   4     ...r/typeinfer.jl:967; typeinf_ext(interp::Co...
#     ╎    ╎    ╎    4     .../typeinfer.jl:213; typeinf(interp::Core.C...
#     ╎    ╎    ╎     3     .../typeinfer.jl:230; _typeinf(interp::Core...
#     ╎    ╎    ╎    ╎ 3     ...pretation.jl:2462; typeinf_nocycle(inte...
#     ╎    ╎    ╎    ╎  3     ...pretation.jl:2340; typeinf_local(inter...
#     ╎    ╎    ╎    ╎   3     ...retation.jl:1890; abstract_eval_state...
#     ╎    ╎    ╎    ╎    3     ...retation.jl:1733; abstract_call(inte...
#     ╎    ╎    ╎    ╎     3     ...retation.jl:1766; abstract_call(inte...
#     ╎    ╎    ╎    ╎    ╎ 3     ...etation.jl:1696; abstract_call_kno...
#     ╎    ╎    ╎    ╎    ╎  1     ...etation.jl:63; abstract_call_gf_...
#    1╎    ╎    ╎    ╎    ╎   1     ...etation.jl:315; find_matching_me...
#     ╎    ╎    ╎    ╎    ╎  1     ...etation.jl:153; abstract_call_gf_...
#     ╎    ╎    ╎    ╎    ╎   1     ...etation.jl:641; abstract_call_me...
#     ╎    ╎    ╎    ╎    ╎    1     ...einfer.jl:877; typeinf_edge(int...
#     ╎    ╎    ╎    ╎    ╎     1     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...einfer.jl:230; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎  1     ...tation.jl:2462; typeinf_nocycle...
#     ╎    ╎    ╎    ╎    ╎    ╎   1     ...tation.jl:2366; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    1     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎     1     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...tation.jl:1696; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...tation.jl:153; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...tation.jl:641; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     ...einfer.jl:877; typeinf_edge(in...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...einfer.jl:257; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...timize.jl:504; optimize
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...timize.jl:539; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     ...lining.jl:85; ssa_inlining_pa...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +1 1     ...lining.jl:640; batch_inline!(t...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +2 1     ...air/ir.jl:1308; iterate(compact...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +3 1     ...air/ir.jl:1036; process_node!(c...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +4 1     ...air/ir.jl:911; renumber_ssa2!(...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +5 1     ...air/ir.jl:895; renumber_ssa2
#     ╎    ╎    ╎    ╎    ╎  1     ...etation.jl:162; abstract_call_gf_...
#     ╎    ╎    ╎    ╎    ╎   1     ...etation.jl:850; abstract_call_me...
#     ╎    ╎    ╎    ╎    ╎    1     ...einfer.jl:213; typeinf(interp::...
#     ╎    ╎    ╎    ╎    ╎     1     ...einfer.jl:230; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...tation.jl:2462; typeinf_nocycle...
#    1╎    ╎    ╎    ╎    ╎    ╎  1     ...tation.jl:2377; typeinf_local(i...
#     ╎    ╎    ╎     1     .../typeinfer.jl:257; _typeinf(interp::Core...
#     ╎    ╎    ╎    ╎ 1     ...r/optimize.jl:504; optimize
#     ╎    ╎    ╎    ╎  1     .../optimize.jl:542; run_passes(ci::Core....
#     ╎    ╎    ╎    ╎   1     ...ir/passes.jl:750; sroa_pass!(ir::Core...
#     ╎    ╎    ╎    ╎    1     ...r/passes.jl:508; lift_comparison!(#u...
#     ╎    ╎    ╎    ╎     1     ...r/passes.jl:557; lift_comparison_le...
#     ╎    ╎    ╎    ╎    ╎ 1     ...r/passes.jl:595; perform_lifting!(c...
#     ╎    ╎    ╎    ╎    ╎  1     ...sair/ir.jl:702; insert_node!
#     ╎    ╎    ╎    ╎    ╎   1     ...sair/ir.jl:707; insert_node!(com...
#     ╎    ╎    ╎    ╎    ╎    1     ...air/ir.jl:274; add!
#     ╎    ╎    ╎    ╎    ╎     1     ...air/ir.jl:234; Instruction
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...air/ir.jl:204; add!
#     ╎    ╎    ╎    ╎    ╎    ╎  1     ...air/ir.jl:221; resize!(stmts::...
#     ╎    ╎    ╎    ╎    ╎    ╎   1     .../array.jl:1236; resize!
#    1╎    ╎    ╎    ╎    ╎    ╎    1     .../array.jl:1011; _growend!
#     ╎    ╎    ╎ 1     ...ngconstructs.jl:38; threading_run(fun::var"#...
#     ╎    ╎    ╎  1     @Base/task.jl:343; wait
#     ╎    ╎    ╎   1     @Base/task.jl:304; _wait(t::Task)
#     ╎    ╎    ╎    1     .../condition.jl:124; wait(c::Base.GenericCo...
#     ╎    ╎    ╎     1     @Base/task.jl:930; wait()
#    1╎    ╎    ╎    ╎ 1     @Base/task.jl:921; poptask(W::Base.Invas...
#     ╎    ╎   21    ...ler/typeinfer.jl:996; typeinf_ext_toplevel(mi::...
#     ╎    ╎    21    ...er/typeinfer.jl:1000; typeinf_ext_toplevel(int...
#     ╎    ╎     21    ...er/typeinfer.jl:967; typeinf_ext(interp::Core...
#     ╎    ╎    ╎ 21    ...er/typeinfer.jl:213; typeinf(interp::Core.Com...
#     ╎    ╎    ╎  21    ...r/typeinfer.jl:230; _typeinf(interp::Core.C...
#     ╎    ╎    ╎   21    ...rpretation.jl:2462; typeinf_nocycle(interp...
#     ╎    ╎    ╎    21    ...rpretation.jl:2366; typeinf_local(interp:...
#     ╎    ╎    ╎     21    ...rpretation.jl:1890; abstract_eval_stateme...
#     ╎    ╎    ╎    ╎ 21    ...pretation.jl:1733; abstract_call(interp...
#     ╎    ╎    ╎    ╎  21    ...pretation.jl:1766; abstract_call(inter...
#     ╎    ╎    ╎    ╎   1     ...retation.jl:1695; abstract_call_known...
#     ╎    ╎    ╎    ╎    1     ...typeutils.jl:44; argtypes_to_type
#     ╎    ╎    ╎    ╎     1     ...tilities.jl:43; anymap(f::Core.Comp...
#     ╎    ╎    ╎    ╎    ╎ 1     ...ypeutils.jl:44; (::Core.Compiler.v...
#    1╎    ╎    ╎    ╎    ╎  1     ...lattice.jl:335; widenconst(::Core...
#     ╎    ╎    ╎    ╎   20    ...retation.jl:1696; abstract_call_known...
#     ╎    ╎    ╎    ╎    20    ...retation.jl:153; abstract_call_gf_by...
#     ╎    ╎    ╎    ╎     20    ...retation.jl:641; abstract_call_meth...
#     ╎    ╎    ╎    ╎    ╎ 20    ...ypeinfer.jl:877; typeinf_edge(inter...
#     ╎    ╎    ╎    ╎    ╎  20    ...peinfer.jl:213; typeinf(interp::C...
#     ╎    ╎    ╎    ╎    ╎   12    ...peinfer.jl:230; _typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    12    ...tation.jl:2462; typeinf_nocycle...
#     ╎    ╎    ╎    ╎    ╎     3     ...tation.jl:2340; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎ 3     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎  3     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎   3     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    3     ...tation.jl:1696; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎     3     ...tation.jl:162; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 3     ...tation.jl:850; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎  3     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎   3     ...einfer.jl:230; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    3     ...tation.jl:2462; typeinf_nocycle...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎     3     ...tation.jl:2366; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 3     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  3     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   3     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    3     ...tation.jl:1696; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     3     ...tation.jl:162; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +1 3     ...tation.jl:850; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +2 3     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +3 2     ...einfer.jl:230; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +4 2     ...tation.jl:2462; typeinf_nocycle...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +5 2     ...tation.jl:2366; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +6 2     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +7 2     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +8 2     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +9 2     ...tation.jl:1696; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +10 2     ...tation.jl:162; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +11 2     ...tation.jl:850; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +12 2     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +13 1     ...einfer.jl:230; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +14 1     ...tation.jl:2462; typeinf_nocycle...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +15 1     ...tation.jl:2366; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +16 1     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +17 1     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +18 1     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +19 1     ...tation.jl:1696; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +20 1     ...tation.jl:162; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +21 1     ...tation.jl:850; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +22 1     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +23 1     ...einfer.jl:230; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +24 1     ...tation.jl:2462; typeinf_nocycle...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +25 1     ...tation.jl:2366; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +26 1     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +27 1     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +28 1     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +29 1     ...tation.jl:1696; abstract_call_k...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +30 1     ...tation.jl:227; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +13 1     ...einfer.jl:257; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +14 1     ...timize.jl:504; optimize
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +15 1     ...timize.jl:536; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +16 1     ...timize.jl:645; slot2reg
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +17 1     ...ot2ssa.jl:907; construct_ssa!(...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +18 1     ...ot2ssa.jl:506; domsort_ssa!(ir...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +19 1     ...ot2ssa.jl:62; renumber_ssa!
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +20 1     ...air/ir.jl:505; ssamap(f::Core....
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +21 1     ...air/ir.jl:0; iterate(it::Cor...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +3 1     ...einfer.jl:257; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +4 1     ...timize.jl:504; optimize
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +5 1     ...timize.jl:541; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +6 1     ...air/ir.jl:1459; compact!
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +7 1     ...air/ir.jl:1462; compact!(code::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +8 1     ...air/ir.jl:1447; finish(compact:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +9 1     ...air/ir.jl:1438; non_dce_finish!
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +10 1     ...air/ir.jl:1408; just_fixup!(com...
#     ╎    ╎    ╎    ╎    ╎     9     ...tation.jl:2366; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎ 9     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎  9     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎   9     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    1     ...tation.jl:1695; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎     1     ...eutils.jl:44; argtypes_to_type
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...lities.jl:43; anymap(f::Core....
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...eutils.jl:44; (::Core.Compile...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...attice.jl:335; widenconst(::Co...
#     ╎    ╎    ╎    ╎    ╎    ╎    8     ...tation.jl:1696; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎     3     ...tation.jl:153; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 3     ...tation.jl:641; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎  3     ...einfer.jl:877; typeinf_edge(in...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎   3     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    2     ...einfer.jl:230; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎     2     ...tation.jl:2462; typeinf_nocycle...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...tation.jl:2340; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     ...tation.jl:1696; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +1 1     ...tation.jl:63; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +2 1     ...tation.jl:320; find_matching_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +3 1     ...dtable.jl:107; findall##kw
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +4 1     ...dtable.jl:113; findall(sig::Ty...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +5 1     ...iddict.jl:178; get!
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +6 1     ...dtable.jl:114; (::Core.Compile...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +7 1     ...dtable.jl:68; findall##kw
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +8 1     ...dtable.jl:69; #findall#248
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +9 1     ...dtable.jl:100; _findall
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +10 1     ...ection.jl:945; _methods_by_ftype
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...tation.jl:2404; typeinf_local(i...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     .../array.jl:924; getindex
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...einfer.jl:277; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     ...einfer.jl:395; cache_result!(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...einfer.jl:364; transform_resul...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...timize.jl:147; ir_to_codeinf!
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...einfer.jl:550; widen_all_const...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...attice.jl:335; widenconst(::Co...
#     ╎    ╎    ╎    ╎    ╎    ╎     5     ...tation.jl:162; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 5     ...tation.jl:850; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎  5     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎   3     ...einfer.jl:230; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    3     ...tation.jl:2462; typeinf_nocycle...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎     3     ...tation.jl:2366; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 3     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  3     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   3     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    3     ...tation.jl:1696; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     3     ...tation.jl:162; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +1 3     ...tation.jl:850; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +2 3     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +3 2     ...einfer.jl:230; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +4 2     ...tation.jl:2462; typeinf_nocycle...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +5 2     ...tation.jl:2366; typeinf_local(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +6 2     ...tation.jl:1890; abstract_eval_s...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +7 2     ...tation.jl:1733; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +8 2     ...tation.jl:1766; abstract_call(i...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +9 2     ...tation.jl:1696; abstract_call_k...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +10 2     ...tation.jl:162; abstract_call_g...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +11 1     ...tation.jl:847; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +12 1     ...estate.jl:287; Core.Compiler.I...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +13 1     ...estate.jl:104; Core.Compiler.I...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +14 1     ...lities.jl:248; find_ssavalue_u...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +15 1     ...bitset.jl:18; BitSet
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +16 1     .../array.jl:584; zeros
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +17 1     .../array.jl:588; zeros
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +18 1     ...e/boot.jl:468; Array
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +19 1     ...e/boot.jl:459; Array
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +11 1     ...tation.jl:850; abstract_call_m...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +12 1     ...einfer.jl:213; typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +13 1     ...einfer.jl:257; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +14 1     ...timize.jl:504; optimize
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +15 1     ...timize.jl:539; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +16 1     ...lining.jl:82; ssa_inlining_pa...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +17 1     ...lining.jl:1359; assemble_inline...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +18 1     ...lining.jl:1120; process_simple!...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +19 1     ...lining.jl:955; call_sig(ir::Co...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +20 1     ...e/boot.jl:459; Array
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +3 1     ...einfer.jl:257; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +4 1     ...timize.jl:504; optimize
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +5 1     ...timize.jl:536; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +6 1     ...timize.jl:643; slot2reg
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +7 1     ...omtree.jl:204; construct_domtr...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +8 1     ...omtree.jl:218; update_domtree!
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +9 1     ...omtree.jl:224; compute_domtree...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +10 1     .../array.jl:679; _array_for
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +11 1     .../array.jl:676; _array_for
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +12 1     ...tarray.jl:840; similar
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +13 1     ...tarray.jl:841; similar
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +14 1     ...e/boot.jl:468; Array
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ +15 1     ...e/boot.jl:459; Array
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎   2     ...einfer.jl:257; _typeinf(interp...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    2     ...timize.jl:504; optimize
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     ...timize.jl:539; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...lining.jl:82; ssa_inlining_pa...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...lining.jl:1359; assemble_inline...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...lining.jl:1150; process_simple!...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...lining.jl:1092; check_effect_free!
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     ...timize.jl:219; stmt_effect_fre...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +1 1     ...tfuncs.jl:1732; _builtin_nothro...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +2 1     ...tfuncs.jl:729; getfield_nothrow
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  +3 1     ...tfuncs.jl:763; getfield_nothro...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎     1     ...timize.jl:542; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...passes.jl:813; sroa_pass!(ir::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...passes.jl:347; lift_leaves(com...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...iddict.jl:30; IdDict
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...e/boot.jl:459; Array
#     ╎    ╎    ╎    ╎    ╎   6     ...peinfer.jl:257; _typeinf(interp:...
#     ╎    ╎    ╎    ╎    ╎    6     ...timize.jl:504; optimize
#     ╎    ╎    ╎    ╎    ╎     4     ...timize.jl:539; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎ 2     ...lining.jl:82; ssa_inlining_pa...
#     ╎    ╎    ╎    ╎    ╎    ╎  2     ...lining.jl:1420; assemble_inline...
#     ╎    ╎    ╎    ╎    ╎    ╎   2     ...lining.jl:1205; analyze_single_...
#     ╎    ╎    ╎    ╎    ╎    ╎    2     ...lining.jl:1288; handle_match!(m...
#     ╎    ╎    ╎    ╎    ╎    ╎     2     ...lining.jl:861; analyze_method!...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 2     ...lining.jl:804; resolve_todo(to...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...lining.jl:870; InliningTodo
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...lining.jl:873; InliningTodo
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...legacy.jl:10; inflate_ir(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...legacy.jl:24; inflate_ir(ci::...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎     1     .../array.jl:966; setindex!
#     ╎    ╎    ╎    ╎    ╎    ╎ 2     ...lining.jl:85; ssa_inlining_pa...
#     ╎    ╎    ╎    ╎    ╎    ╎  2     ...lining.jl:622; batch_inline!(t...
#     ╎    ╎    ╎    ╎    ╎    ╎   2     ...lining.jl:522; ir_inline_union...
#     ╎    ╎    ╎    ╎    ╎    ╎    2     ...lining.jl:402; ir_inline_item!...
#     ╎    ╎    ╎    ╎    ╎    ╎     2     ...lining.jl:1520; ssa_substitute!
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...lining.jl:1560; ssa_substitute_...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...air/ir.jl:456; userefs
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...air/ir.jl:344; UseRefIterator
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...air/ir.jl:338; UseRef
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...lining.jl:1562; ssa_substitute_...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎  1     ...lining.jl:1560; ssa_substitute_...
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎   1     ...air/ir.jl:456; userefs
#     ╎    ╎    ╎    ╎    ╎    ╎    ╎    1     ...air/ir.jl:344; UseRefIterator
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎     1     ...air/ir.jl:338; UseRef
#     ╎    ╎    ╎    ╎    ╎     1     ...timize.jl:542; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...passes.jl:837; sroa_pass!(ir::...
#     ╎    ╎    ╎    ╎    ╎    ╎  1     ...air/ir.jl:1308; iterate(compact...
#     ╎    ╎    ╎    ╎    ╎    ╎   1     ...air/ir.jl:1036; process_node!(c...
#     ╎    ╎    ╎    ╎    ╎    ╎    1     ...air/ir.jl:917; renumber_ssa2!(...
#    1╎    ╎    ╎    ╎    ╎    ╎     1     ...air/ir.jl:467; iterate(it::Cor...
#     ╎    ╎    ╎    ╎    ╎     1     ...timize.jl:543; run_passes(ci::...
#     ╎    ╎    ╎    ╎    ╎    ╎ 1     ...passes.jl:1119; adce_pass!(ir::...
#     ╎    ╎    ╎    ╎    ╎    ╎  1     ...passes.jl:5; is_known_call(x...
#     ╎    ╎    ╎    ╎    ╎    ╎   1     ...timize.jl:338; argextype
#     ╎    ╎    ╎    ╎    ╎    ╎    1     ...timize.jl:339; argextype
#     ╎    ╎    ╎    ╎    ╎    ╎     1     ...timize.jl:365; argextype(x::An...
#    1╎    ╎    ╎    ╎    ╎    ╎    ╎ 1     ...tation.jl:2081; abstract_eval_g...
#     ╎    ╎    ╎    ╎    ╎   2     ...peinfer.jl:277; _typeinf(interp:...
# ...
#     ╎    ╎    ╎ 3     @Base/broadcast.jl:961; macro expansion
#     ╎    ╎    ╎  3     ...dimensional.jl:674; setindex!
#    3╎    ╎    ╎   3     @Base/array.jl:968; setindex!
#     ╎    ╎   1     @Base/broadcast.jl:211; similar
#     ╎    ╎    1     @Base/broadcast.jl:212; similar
#     ╎    ╎     1     ...bstractarray.jl:840; similar
#     ╎    ╎    ╎ 1     ...bstractarray.jl:841; similar
#     ╎    ╎    ╎  1     @Base/boot.jl:476; Array
#     ╎    ╎    ╎   1     @Base/boot.jl:469; Array
#    1╎    ╎    ╎    1     @Base/boot.jl:461; Array
#     ╎    ╎ 1     @Base/reducedim.jl:406; reduce##kw
#     ╎    ╎  1     @Base/reducedim.jl:406; #reduce#767
#     ╎    ╎   1     @Base/reducedim.jl:357; mapreduce##kw
#     ╎    ╎    1     @Base/reducedim.jl:357; #mapreduce#765
#     ╎    ╎     1     @Base/reducedim.jl:371; _mapreduce_dim
#     ╎    ╎    ╎ 1     @Base/reducedim.jl:219; reducedim_init
#     ╎    ╎    ╎  1     @Base/reducedim.jl:92; reducedim_initarray
#     ╎    ╎    ╎   1     ...e/reducedim.jl:91; reducedim_initarray(A::...
#     ╎    ╎    ╎    1     ...tractarray.jl:803; similar
#     ╎    ╎    ╎     1     @Base/array.jl:378; similar
#     ╎    ╎    ╎    ╎ 1     @Base/boot.jl:469; Array
#    1╎    ╎    ╎    ╎  1     @Base/boot.jl:461; Array
#     ╎ 2475  ...eadingconstructs.jl:51; #49#threadsfor_fun
#     ╎  2475  ...eadingconstructs.jl:84; (::var"#49#threadsfor_fun#42"{...
#     ╎   2475  In[10]:61; macro expansion
#    1╎    1     .../abstractarray.jl:1341; setindex!(::Matrix{Float64}...
#     ╎    57    .../abstractarray.jl:1344; setindex!(::Matrix{Float64}...
#     ╎     57    ...ltidimensional.jl:930; _setindex!
#     ╎    ╎ 57    ...ltidimensional.jl:941; _unsafe_setindex!(::IndexLi...
#     ╎    ╎  56    @Base/cartesian.jl:64; macro expansion
#    1╎    ╎   1     ...tidimensional.jl:944; macro expansion
#     ╎    ╎   49    ...tidimensional.jl:946; macro expansion
#   49╎    ╎    49    @Base/array.jl:968; setindex!
#     ╎    ╎   6     ...tidimensional.jl:947; macro expansion
#     ╎    ╎    6     @Base/array.jl:898; iterate
#    1╎    ╎     1     @Base/array.jl:924; getindex
#    3╎    ╎     3     @Base/int.jl:87; +
#     ╎    ╎     1     @Base/int.jl:991; -
#    1╎    ╎    ╎ 1     @Base/int.jl:86; -
#     ╎    ╎     1     @Base/int.jl:487; <
#    1╎    ╎    ╎ 1     @Base/int.jl:480; <
#     ╎    ╎  1     @Base/cartesian.jl:66; macro expansion
#     ╎    ╎   1     @Base/indices.jl:367; iterate
#     ╎    ╎    1     @Base/range.jl:883; iterate
#    1╎    ╎     1     @Base/promotion.jl:477; ==
#     ╎    2417  ...LMM.jl/src/wls.jl:146; rss
#     ╎     1792  ...LMM.jl/src/wls.jl:148; rss(y::Matrix{Float64}, X::...
#     ╎    ╎ 1792  ...LMM.jl/src/wls.jl:189; resid##kw
#    1╎    ╎  1     ...ebra/src/blas.jl:387; dot(x::SubArray{Float64, 1...
#     ╎    ╎  614   ...MM.jl/src/wls.jl:194; resid(y::Matrix{Float64}, ...
#     ╎    ╎   48    @Base/arraymath.jl:21; \
#     ╎    ╎    48    ...src/adjtrans.jl:252; broadcast_preserving_zero_d
#     ╎    ╎     48    @Base/broadcast.jl:798; broadcast(::LinearAlgebr...
#     ╎    ╎    ╎ 48    @Base/broadcast.jl:860; materialize
#     ╎    ╎    ╎  48    ...e/broadcast.jl:885; copy
#     ╎    ╎    ╎   23    ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎    23    .../broadcast.jl:960; copyto!
#     ╎    ╎    ╎     23    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎ 23    .../broadcast.jl:961; macro expansion
#   22╎    ╎    ╎    ╎  22    @Base/array.jl:966; setindex!
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎   1     ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:670; _broadcast_getindex...
#     ╎    ╎    ╎    ╎     1     ...adjtrans.jl:252; #9
#     ╎    ╎    ╎    ╎    ╎ 1     ...perators.jl:629; \
#    1╎    ╎    ╎    ╎    ╎  1     ...e/float.jl:386; /
#     ╎    ╎    ╎   25    ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎    25    .../broadcast.jl:212; similar
#     ╎    ╎    ╎     25    ...tractarray.jl:840; similar
#     ╎    ╎    ╎    ╎ 25    ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎  25    @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎   25    @Base/boot.jl:468; Array
#   25╎    ╎    ╎    ╎    25    @Base/boot.jl:459; Array
#     ╎    ╎   5     .../src/adjtrans.jl:295; *
#     ╎    ╎    5     ...ra/src/matmul.jl:14; dot
#     ╎    ╎     5     ...bra/src/blas.jl:390; dot(x::SubArray{Float64,...
#    5╎    ╎    ╎ 5     ...bra/src/blas.jl:340; dot
#     ╎    ╎   561   ...ra/src/matmul.jl:119; *
#     ╎    ╎    561   ...a/src/matmul.jl:101; *
#     ╎    ╎     9     ...bstractarray.jl:797; similar
#     ╎    ╎    ╎ 9     @Base/subarray.jl:65; similar
#     ╎    ╎    ╎  9     @Base/array.jl:378; similar
#     ╎    ╎    ╎   9     @Base/boot.jl:468; Array
#    9╎    ╎    ╎    9     @Base/boot.jl:459; Array
#     ╎    ╎     552   ...a/src/matmul.jl:276; mul!
#     ╎    ╎    ╎ 552   ...a/src/matmul.jl:109; mul!
#     ╎    ╎    ╎  552   ...a/src/matmul.jl:93; mul!
#     ╎    ╎    ╎   552   .../src/matmul.jl:503; gemv!(y::Vector{Float6...
#  552╎    ╎    ╎    552   ...a/src/blas.jl:666; gemv!(trans::Char, alp...
#     ╎    ╎  568   ...MM.jl/src/wls.jl:204; resid(y::Matrix{Float64}, ...
#     ╎    ╎   568   .../src/adjtrans.jl:301; *
#    1╎    ╎    568   @Base/broadcast.jl:798; broadcast(::typeof(*), ::...
#     ╎    ╎     567   @Base/broadcast.jl:860; materialize
#     ╎    ╎    ╎ 567   @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  503   ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   4     ...e/broadcast.jl:957; copyto!
#     ╎    ╎    ╎    4     .../broadcast.jl:940; preprocess
#     ╎    ╎    ╎     4     .../broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:944; preprocess_args
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:941; preprocess
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:637; extrude
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎     4     ...roadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎    ╎ 4     ...roadcast.jl:591; _newindexer
#     ╎    ╎    ╎    ╎    ╎  4     ...oadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎   4     ...erators.jl:282; !=
#    4╎    ╎    ╎    ╎    ╎    4     ...motion.jl:477; ==
#     ╎    ╎    ╎   497   ...e/broadcast.jl:960; copyto!
#    2╎    ╎    ╎    2     @Base/simdloop.jl:0; macro expansion
#    5╎    ╎    ╎    7     @Base/simdloop.jl:75; macro expansion
#    2╎    ╎    ╎     2     @Base/int.jl:83; <
#     ╎    ╎    ╎    71    @Base/simdloop.jl:76; macro expansion
#     ╎    ╎    ╎     71    ...imensional.jl:480; simd_index
#   71╎    ╎    ╎    ╎ 71    @Base/int.jl:87; +
#     ╎    ╎    ╎    412   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     412   .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 25    .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  11    ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   11    ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    11    ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎     11    ...actarray.jl:1241; getindex
#     ╎    ╎    ╎    ╎    ╎ 11    ...ctarray.jl:1269; _getindex
#     ╎    ╎    ╎    ╎    ╎  11    ...ubarray.jl:315; getindex
#   11╎    ╎    ╎    ╎    ╎   11    ...e/array.jl:924; getindex
#     ╎    ╎    ╎    ╎  14    ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   14    ...broadcast.jl:670; _broadcast_getindex...
#   14╎    ╎    ╎    ╎    14    @Base/float.jl:385; *
#     ╎    ╎    ╎    ╎ 387   ...imensional.jl:674; setindex!
#  387╎    ╎    ╎    ╎  387   @Base/array.jl:968; setindex!
#    4╎    ╎    ╎    5     @Base/simdloop.jl:84; macro expansion
#     ╎    ╎    ╎     1     ...imensional.jl:404; iterate
#     ╎    ╎    ╎    ╎ 1     ...imensional.jl:422; __inc
#    1╎    ╎    ╎    ╎  1     @Base/int.jl:87; +
#    2╎    ╎    ╎   2     @Base/simdloop.jl:0; copyto!
#     ╎    ╎    ╎  64    ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎   64    ...e/broadcast.jl:212; similar
#     ╎    ╎    ╎    64    ...tractarray.jl:840; similar
#     ╎    ╎    ╎     64    ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎ 64    @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎  64    @Base/boot.jl:469; Array
#   64╎    ╎    ╎    ╎   64    @Base/boot.jl:461; Array
#     ╎    ╎  609   ...MM.jl/src/wls.jl:205; resid(y::Matrix{Float64}, ...
#    1╎    ╎   1     @Base/arraymath.jl:7; -(A::Matrix{Float64}, B::Ma...
#     ╎    ╎   608   @Base/arraymath.jl:8; -(A::Matrix{Float64}, B::Ma...
#     ╎    ╎    608   @Base/broadcast.jl:849; broadcast_preserving_zero_d
#     ╎    ╎     608   @Base/broadcast.jl:860; materialize
#     ╎    ╎    ╎ 608   @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  557   ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   4     ...e/broadcast.jl:957; copyto!
#     ╎    ╎    ╎    4     .../broadcast.jl:940; preprocess
#     ╎    ╎    ╎     4     .../broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:941; preprocess
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:637; extrude
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:591; _newindexer
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎  2     ...erators.jl:282; !=
#    2╎    ╎    ╎    ╎    ╎   2     ...omotion.jl:477; ==
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎ 2     ...perators.jl:282; !=
#    2╎    ╎    ╎    ╎    ╎  2     ...omotion.jl:477; ==
#     ╎    ╎    ╎   553   ...e/broadcast.jl:960; copyto!
#    3╎    ╎    ╎    3     @Base/simdloop.jl:0; macro expansion
#    9╎    ╎    ╎    11    @Base/simdloop.jl:75; macro expansion
#    2╎    ╎    ╎     2     @Base/int.jl:83; <
#     ╎    ╎    ╎    527   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     527   .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 164   .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  72    ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   72    ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    72    ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎     72    ...ensional.jl:672; getindex
#   72╎    ╎    ╎    ╎    ╎ 72    @Base/array.jl:925; getindex
#     ╎    ╎    ╎    ╎  92    ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   92    ...broadcast.jl:670; _broadcast_getindex...
#   92╎    ╎    ╎    ╎    92    @Base/float.jl:384; -
#     ╎    ╎    ╎    ╎ 363   ...imensional.jl:674; setindex!
#  363╎    ╎    ╎    ╎  363   @Base/array.jl:968; setindex!
#     ╎    ╎    ╎    10    @Base/simdloop.jl:78; macro expansion
#   10╎    ╎    ╎     10    @Base/int.jl:87; +
#     ╎    ╎    ╎    2     @Base/simdloop.jl:84; macro expansion
#     ╎    ╎    ╎     2     ...imensional.jl:404; iterate
#    2╎    ╎    ╎    ╎ 2     ...imensional.jl:423; __inc
#     ╎    ╎    ╎  51    ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎   51    ...e/broadcast.jl:212; similar
#     ╎    ╎    ╎    51    ...tractarray.jl:840; similar
#     ╎    ╎    ╎     51    ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎ 51    @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎  51    @Base/boot.jl:469; Array
#   51╎    ╎    ╎    ╎   51    @Base/boot.jl:461; Array
#     ╎     625   ...LMM.jl/src/wls.jl:149; rss(y::Matrix{Float64}, X::...
#     ╎    ╎ 510   @Base/broadcast.jl:860; materialize
#     ╎    ╎  510   @Base/broadcast.jl:885; copy
#     ╎    ╎   448   @Base/broadcast.jl:913; copyto!
#     ╎    ╎    2     @Base/broadcast.jl:957; copyto!
#     ╎    ╎     2     @Base/broadcast.jl:940; preprocess
#     ╎    ╎    ╎ 2     @Base/broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎  2     ...e/broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎   2     ...e/broadcast.jl:941; preprocess
#     ╎    ╎    ╎    2     .../broadcast.jl:637; extrude
#     ╎    ╎    ╎     2     .../broadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:591; _newindexer
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    2     ...perators.jl:282; !=
#    2╎    ╎    ╎    ╎     2     ...romotion.jl:477; ==
#     ╎    ╎    446   @Base/broadcast.jl:960; copyto!
#    3╎    ╎     3     @Base/simdloop.jl:75; macro expansion
#     ╎    ╎     432   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎ 432   @Base/broadcast.jl:961; macro expansion
#     ╎    ╎    ╎  176   ...e/broadcast.jl:597; getindex
#     ╎    ╎    ╎   95    ...e/broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    95    .../broadcast.jl:666; _getindex
#     ╎    ╎    ╎     95    .../broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎ 95    .../broadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎  95    ...mensional.jl:672; getindex
#   95╎    ╎    ╎    ╎   95    @Base/array.jl:925; getindex
#     ╎    ╎    ╎   81    ...e/broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    81    .../broadcast.jl:670; _broadcast_getindex_evalf
#     ╎    ╎    ╎     81    ...e/intfuncs.jl:321; literal_pow
#   81╎    ╎    ╎    ╎ 81    @Base/float.jl:385; *
#     ╎    ╎    ╎  256   ...dimensional.jl:674; setindex!
#  256╎    ╎    ╎   256   @Base/array.jl:968; setindex!
#     ╎    ╎     7     @Base/simdloop.jl:78; macro expansion
#    7╎    ╎    ╎ 7     @Base/int.jl:87; +
#    3╎    ╎     4     @Base/simdloop.jl:84; macro expansion
#     ╎    ╎    ╎ 1     ...idimensional.jl:404; iterate
#    1╎    ╎    ╎  1     ...dimensional.jl:423; __inc
#     ╎    ╎   62    @Base/broadcast.jl:211; similar
#     ╎    ╎    62    @Base/broadcast.jl:212; similar
#     ╎    ╎     62    ...bstractarray.jl:840; similar
#     ╎    ╎    ╎ 62    ...bstractarray.jl:841; similar
#     ╎    ╎    ╎  62    @Base/boot.jl:476; Array
#     ╎    ╎    ╎   62    @Base/boot.jl:469; Array
#   62╎    ╎    ╎    62    @Base/boot.jl:461; Array
#     ╎    ╎ 115   @Base/reducedim.jl:406; reduce##kw
#     ╎    ╎  115   @Base/reducedim.jl:406; #reduce#767
#     ╎    ╎   115   @Base/reducedim.jl:357; mapreduce##kw
#     ╎    ╎    115   @Base/reducedim.jl:357; #mapreduce#765
#     ╎    ╎     115   @Base/reducedim.jl:371; _mapreduce_dim
#     ╎    ╎    ╎ 100   @Base/reducedim.jl:324; mapreducedim!
#     ╎    ╎    ╎  99    ...e/reducedim.jl:295; _mapreducedim!(f::typeo...
#    1╎    ╎    ╎   1     @Base/array.jl:924; getindex
#     ╎    ╎    ╎   98    @Base/reduce.jl:272; mapreduce_impl
#     ╎    ╎    ╎    1     @Base/reduce.jl:250; mapreduce_impl(f::type...
#    1╎    ╎    ╎     1     .../promotion.jl:477; ==
#     ╎    ╎    ╎    1     @Base/reduce.jl:255; mapreduce_impl(f::type...
#    1╎    ╎    ╎     1     @Base/array.jl:924; getindex
#     ╎    ╎    ╎    1     @Base/reduce.jl:257; mapreduce_impl(f::type...
#    1╎    ╎    ╎     1     @Base/float.jl:383; +
#     ╎    ╎    ╎    95    @Base/reduce.jl:258; mapreduce_impl(f::type...
#     ╎    ╎    ╎     1     ...e/simdloop.jl:69; macro expansion
#    1╎    ╎    ╎    ╎ 1     @Base/int.jl:87; +
#     ╎    ╎    ╎     1     ...e/simdloop.jl:72; macro expansion
#    1╎    ╎    ╎    ╎ 1     @Base/int.jl:83; <
#   15╎    ╎    ╎     49    ...e/simdloop.jl:75; macro expansion
#   34╎    ╎    ╎    ╎ 34    @Base/int.jl:83; <
#     ╎    ╎    ╎     34    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎ 34    @Base/reduce.jl:260; macro expansion
#   34╎    ╎    ╎    ╎  34    @Base/float.jl:383; +
#     ╎    ╎    ╎     10    ...e/simdloop.jl:78; macro expansion
#   10╎    ╎    ╎    ╎ 10    @Base/int.jl:87; +
#     ╎    ╎    ╎  1     ...e/reducedim.jl:297; _mapreducedim!(f::typeo...
#     ╎    ╎    ╎   1     @Base/range.jl:883; iterate
#    1╎    ╎    ╎    1     .../promotion.jl:477; ==
#     ╎    ╎    ╎ 15    @Base/reducedim.jl:219; reducedim_init
#     ╎    ╎    ╎  15    @Base/reducedim.jl:92; reducedim_initarray
#     ╎    ╎    ╎   15    ...e/reducedim.jl:91; reducedim_initarray(A::...
#     ╎    ╎    ╎    9     ...tractarray.jl:803; similar
#     ╎    ╎    ╎     9     @Base/array.jl:378; similar
#     ╎    ╎    ╎    ╎ 9     @Base/boot.jl:469; Array
#    9╎    ╎    ╎    ╎  9     @Base/boot.jl:461; Array
#     ╎    ╎    ╎    6     @Base/array.jl:353; fill!
#    6╎    ╎    ╎     6     @Base/array.jl:966; setindex!
# Total snapshots: 14024. Utilization: 43% across all threads and tasks. Use the `groupby` kwarg to break down by thread and/or task

# %%
@benchmark scan_null_threads(pheno_y, geno, kinship; reml = false)
# Out:
# BenchmarkTools.Trial: 69 samples with 1 evaluation.
#  Range (min … max):  64.451 ms … 196.889 ms  ┊ GC (min … max): 0.00% … 66.20%
#  Time  (median):     65.947 ms               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   73.162 ms ±  28.645 ms  ┊ GC (mean ± σ):  9.49% ± 15.03%
#
#   █▂
#   ██▇▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▄▁▁▁▁▁▁▁▁▁▄▁▁▄ ▁
#   64.5 ms       Histogram: log(frequency) by time       196 ms <
#
#  Memory estimate: 33.23 MiB, allocs estimate: 73683.

# %%
@benchmark scan_null(pheno_y, geno, kinship; reml = false)
# Out:
# BenchmarkTools.Trial: 120 samples with 1 evaluation.
#  Range (min … max):  27.622 ms … 79.075 ms  ┊ GC (min … max):  0.00% … 50.60%
#  Time  (median):     39.126 ms              ┊ GC (median):     0.00%
#  Time  (mean ± σ):   41.720 ms ± 13.319 ms  ┊ GC (mean ± σ):  16.69% ± 20.85%
#
#   ▆            ▁▆█
#   █▆▃▃▃▃▁▁▃▃▃▃▃███▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▄▃▁▃▆▁▃▄▃▁▁▁▁▁▃▁▁▄ ▃
#   27.6 ms         Histogram: frequency by time        74.3 ms <
#
#  Memory estimate: 33.23 MiB, allocs estimate: 73607.

# %%
tloops_LODs = scan_perms_threads(pheno_y, geno, kinship; nperms = 1024, rndseed = 0, reml = false, original = true)
# Out:
# 1025×7321 Matrix{Float64}:
#  0.00819636  0.00819636  0.00819636  …  0.0449878    0.0128283   0.0128283
#  0.604956    0.604956    0.604956       1.33928      1.29426     1.29426
#  0.0264842   0.0264842   0.0264842      0.16927      0.069518    0.069518
#  0.00585467  0.00585467  0.00585467     0.589608     0.14854     0.14854
#  0.477297    0.477297    0.477297       0.0317133    0.0625366   0.0625366
#  0.140293    0.140293    0.140293    …  0.0400303    0.0338204   0.0338204
#  0.45141     0.45141     0.45141        0.459152     0.278652    0.278652
#  0.179818    0.179818    0.179818       0.0430329    0.0218039   0.0218039
#  0.213351    0.213351    0.213351       0.179031     0.193549    0.193549
#  0.0250041   0.0250041   0.0250041      0.0679043    0.00622826  0.00622826
#  0.801668    0.801668    0.801668    …  0.42936      0.123412    0.123412
#  0.0351507   0.0351507   0.0351507      0.296432     0.0480549   0.0480549
#  0.053255    0.053255    0.053255       0.281489     0.11254     0.11254
#  ⋮                                   ⋱                           ⋮
#  0.0166277   0.0166277   0.0166277      0.0247519    0.00547126  0.00547126
#  0.559311    0.559311    0.559311       0.14572      0.459274    0.459274
#  0.0292394   0.0292394   0.0292394   …  0.877688     0.882021    0.882021
#  0.329046    0.329046    0.329046       0.190101     0.229896    0.229896
#  0.353249    0.353249    0.353249       0.242356     0.061297    0.061297
#  0.012342    0.012342    0.012342       0.000730568  0.00663595  0.00663595
#  0.575783    0.575783    0.575783       0.148134     0.466059    0.466059
#  3.0354e-6   3.0354e-6   3.0354e-6   …  0.123425     0.161648    0.161648
#  0.035881    0.035881    0.035881       0.00285915   0.0961371   0.0961371
#  0.0660576   0.0660576   0.0660576      0.0144162    0.0283441   0.0283441
#  0.0143938   0.0143938   0.0143938      0.00119788   0.00962354  0.00962354
#  0.351892    0.351892    0.351892       0.252087     0.160462    0.160462

# %%
normal_LODs = scan_perms(pheno_y, geno, kinship; nperms = 1024, rndseed = 0, reml = false, original = true)
# Out:
# 1025×7321 Matrix{Float64}:
#  0.00819636  0.00819636  0.00819636  …  0.0449878    0.0128283   0.0128283
#  0.604956    0.604956    0.604956       1.33928      1.29426     1.29426
#  0.0264842   0.0264842   0.0264842      0.16927      0.069518    0.069518
#  0.00585467  0.00585467  0.00585467     0.589608     0.14854     0.14854
#  0.477297    0.477297    0.477297       0.0317133    0.0625366   0.0625366
#  0.140293    0.140293    0.140293    …  0.0400303    0.0338204   0.0338204
#  0.45141     0.45141     0.45141        0.459152     0.278652    0.278652
#  0.179818    0.179818    0.179818       0.0430329    0.0218039   0.0218039
#  0.213351    0.213351    0.213351       0.179031     0.193549    0.193549
#  0.0250041   0.0250041   0.0250041      0.0679043    0.00622826  0.00622826
#  0.801668    0.801668    0.801668    …  0.42936      0.123412    0.123412
#  0.0351507   0.0351507   0.0351507      0.296432     0.0480549   0.0480549
#  0.053255    0.053255    0.053255       0.281489     0.11254     0.11254
#  ⋮                                   ⋱                           ⋮
#  0.0166277   0.0166277   0.0166277      0.0247519    0.00547126  0.00547126
#  0.559311    0.559311    0.559311       0.14572      0.459274    0.459274
#  0.0292394   0.0292394   0.0292394   …  0.877688     0.882021    0.882021
#  0.329046    0.329046    0.329046       0.190101     0.229896    0.229896
#  0.353249    0.353249    0.353249       0.242356     0.061297    0.061297
#  0.012342    0.012342    0.012342       0.000730568  0.00663595  0.00663595
#  0.575783    0.575783    0.575783       0.148134     0.466059    0.466059
#  3.0354e-6   3.0354e-6   3.0354e-6   …  0.123425     0.161648    0.161648
#  0.035881    0.035881    0.035881       0.00285915   0.0961371   0.0961371
#  0.0660576   0.0660576   0.0660576      0.0144162    0.0283441   0.0283441
#  0.0143938   0.0143938   0.0143938      0.00119788   0.00962354  0.00962354
#  0.351892    0.351892    0.351892       0.252087     0.160462    0.160462

# %%
@benchmark scan_perms_threads(pheno_y, geno, kinship; nperms = 1024, rndseed = 0, reml = false, original = true)
# Out:
# BenchmarkTools.Trial: 5 samples with 1 evaluation.
#  Range (min … max):  1.039 s …   1.297 s  ┊ GC (min … max): 4.58% … 2.84%
#  Time  (median):     1.134 s              ┊ GC (median):    7.87%
#  Time  (mean ± σ):   1.146 s ± 95.571 ms  ┊ GC (mean ± σ):  7.93% ± 4.63%
#
#   █            █      █    █                              █
#   █▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁█▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█ ▁
#   1.04 s         Histogram: frequency by time         1.3 s <
#
#  Memory estimate: 13.61 GiB, allocs estimate: 95689.

# %%
@benchmark scan_perms(pheno_y, geno, kinship; nperms = 1024, rndseed = 0, reml = false, original = true)
# Out:
# BenchmarkTools.Trial: 2 samples with 1 evaluation.
#  Range (min … max):  2.656 s …  2.660 s  ┊ GC (min … max): 5.06% … 4.52%
#  Time  (median):     2.658 s             ┊ GC (median):    4.79%
#  Time  (mean ± σ):   2.658 s ± 3.342 ms  ┊ GC (mean ± σ):  4.79% ± 0.38%
#
#   █                                                      █
#   █▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█ ▁
#   2.66 s        Histogram: frequency by time        2.66 s <
#
#  Memory estimate: 13.61 GiB, allocs estimate: 74659.

# %%
function threads12_by_blocks(r0perm::Array{Float64, 2}, X00::Array{Float64, 2}, nblocks::Int64)
    # Does distributed processes of calculations of LOD scores for markers in each block

    p = size(X00, 2);

    ## (Create blocks...)
    
    block_size = ceil(Int, p/nblocks);
    blocks = createBlocks2(p, block_size);
    # blocks = createBlocks(p, nblocks);

    LODs_blocks = tmap(x -> calcLODs_block(r0perm, X00, x), 24, blocks);
    results = reduce(hcat, LODs_blocks);

    return results

end
# Out:
# threads12_by_blocks (generic function with 1 method)

# %%
function scan_perms_threads12(y::Array{Float64,2}, g::Array{Float64,2}, K::Array{Float64,2};
                                reml::Bool = false,
                                nperms::Int64 = 1024, rndseed::Int64 = 0, original::Bool = true,
                                # (options for blocks, nperms distribution methods...)
                                option::String = "by blocks", nblocks::Int64 = 1, ncopies::Int64 = 1, 
                                nprocs::Int64 = 0)

    (y0, X0, lambda0) = transform_rotation(y, g, K); # rotation of data
    (r0, X00) = transform_reweight(y0, X0, lambda0; reml = reml); # reweighting and taking residuals
    r0perm = transform_permute(r0; nperms = nperms, rndseed = rndseed, original = original);

    if option == "by blocks"
        results = threads12_by_blocks(r0perm, X00, nblocks);
    elseif option == "by nperms"
        results = distribute_by_nperms(r0, X00, nperms, ncopies, original);
    else
        throw(error("Option unsupported."))
    end

    return results

end
# Out:
# scan_perms_threads12 (generic function with 1 method)

# %%
using ThreadTools

# %%
@benchmark scan_perms_threads12(pheno_y, geno, kinship; reml = false, nperms = 1024, rndseed = 0, original = true, option = "by blocks", nblocks = 120)
# Out:
# BenchmarkTools.Trial: 5 samples with 1 evaluation.
#  Range (min … max):  924.531 ms …   1.063 s  ┊ GC (min … max): 4.09% … 4.29%
#  Time  (median):        1.017 s              ┊ GC (median):    4.48%
#  Time  (mean ± σ):      1.002 s ± 57.001 ms  ┊ GC (mean ± σ):  5.28% ± 1.34%
#
#   █               █                      █          █        █
#   █▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁█ ▁
#   925 ms          Histogram: frequency by time          1.06 s <
#
#  Memory estimate: 13.67 GiB, allocs estimate: 77074.

# %%
using Profile

# %%
@profile scan_perms_threads(pheno_y, geno, kinship; nperms = 1024, rndseed = 0, reml = false, original = true);

# %%
Profile.print()
# Out:
# Overhead ╎ [+additional indent] Count File:Line; Function
# =========================================================
#    3╎3     @Base/reduce.jl:0; mapreduce_impl(f::typeof(ident...
#    5╎5     @Base/reduce.jl:248; mapreduce_impl(f::typeof(ident...
#     ╎283   @Base/task.jl:484; (::IJulia.var"#15#18")()
#     ╎ 283   ...ia/src/eventloop.jl:8; eventloop(socket::ZMQ.Socket)
#     ╎  283   @Base/essentials.jl:726; invokelatest
#     ╎   283   @Base/essentials.jl:729; #invokelatest#2
#     ╎    283   ...execute_request.jl:67; execute_request(socket::ZMQ....
#     ╎     283   ...oftGlobalScope.jl:65; softscope_include_string(m::...
#     ╎    ╎ 283   @Base/loading.jl:1428; include_string(mapexpr::ty...
#    2╎    ╎  283   @Base/boot.jl:368; eval
#     ╎    ╎   180   In[10]:1; (::var"#scan_perms_threads#...
#     ╎    ╎    1     In[10]:18; scan_perms_threads(y::Mat...
#     ╎    ╎     1     ...M.jl/src/lmm.jl:47; rotateData
#     ╎    ╎    ╎ 1     ...a/src/matmul.jl:148; *
#     ╎    ╎    ╎  1     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎   1     .../src/matmul.jl:425; mul!
#     ╎    ╎    ╎    1     ...src/matmul.jl:378; mul!
#     ╎    ╎    ╎     1     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    1╎    ╎    ╎    ╎ 1     .../src/blas.jl:1514; gemm!(transA::Char, ...
#     ╎    ╎    4     In[10]:38; scan_perms_threads(y::Mat...
#     ╎    ╎     2     ...bstractarray.jl:1241; getindex
#     ╎    ╎    ╎ 2     ...idimensional.jl:875; _getindex
#     ╎    ╎    ╎  2     ...dimensional.jl:889; _unsafe_getindex(::Inde...
#     ╎    ╎    ╎   2     ...dimensional.jl:898; _unsafe_getindex!
#     ╎    ╎    ╎    2     ...e/cartesian.jl:64; macro expansion
#     ╎    ╎    ╎     1     ...imensional.jl:903; macro expansion
#    1╎    ╎    ╎    ╎ 1     @Base/array.jl:966; setindex!
#     ╎    ╎    ╎     1     ...imensional.jl:904; macro expansion
#     ╎    ╎    ╎    ╎ 1     @Base/range.jl:883; iterate
#    1╎    ╎    ╎    ╎  1     ...promotion.jl:477; ==
#     ╎    ╎     2     ...M.jl/src/wls.jl:167; resid
#     ╎    ╎    ╎ 1     ...M.jl/src/wls.jl:172; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  1     ...src/generic.jl:1102; \(A::Matrix{Float64}, ...
#     ╎    ╎    ╎   1     ...rc/diagonal.jl:73; Diagonal
#     ╎    ╎    ╎    1     .../src/dense.jl:249; diag
#     ╎    ╎    ╎     1     .../src/dense.jl:249; diag(A::Matrix{Float6...
#     ╎    ╎    ╎    ╎ 1     .../src/dense.jl:225; diagind
#     ╎    ╎    ╎    ╎  1     ...src/dense.jl:201; diagind
#     ╎    ╎    ╎    ╎   1     @Base/range.jl:138; range##kw
#     ╎    ╎    ╎    ╎    1     @Base/range.jl:138; #range#68
#     ╎    ╎    ╎    ╎     1     @Base/range.jl:159; _range
#     ╎    ╎    ╎    ╎    ╎ 1     @Base/range.jl:207; range_start_step_l...
#     ╎    ╎    ╎    ╎    ╎  1     ...e/range.jl:316; StepRange
#    1╎    ╎    ╎    ╎    ╎   1     ...e/range.jl:321; steprange_last(s...
#     ╎    ╎    ╎ 1     ...M.jl/src/wls.jl:182; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  1     .../src/matmul.jl:148; *
#     ╎    ╎    ╎   1     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎    1     ...src/matmul.jl:161; mul!
#     ╎    ╎    ╎     1     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    1╎    ╎    ╎    ╎ 1     .../src/blas.jl:1514; gemm!(transA::Char, ...
#     ╎    ╎    3     In[10]:43; scan_perms_threads(y::Mat...
#     ╎    ╎     3     ....jl/src/util.jl:152; shuffleVector##kw
#     ╎    ╎    ╎ 3     ....jl/src/util.jl:165; shuffleVector(rng::Merse...
#     ╎    ╎    ╎  3     ...om/src/misc.jl:256; shuffle
#     ╎    ╎    ╎   2     ...tractarray.jl:1152; copymutable
#     ╎    ╎    ╎    1     @Base/array.jl:346; copyto!
#     ╎    ╎    ╎     1     @Base/array.jl:322; copyto!
#     ╎    ╎    ╎    ╎ 1     @Base/array.jl:331; _copyto_impl!(dest::V...
#    1╎    ╎    ╎    ╎  1     @Base/array.jl:289; unsafe_copyto!
#     ╎    ╎    ╎    1     @Base/array.jl:373; similar
#    1╎    ╎    ╎     1     @Base/boot.jl:459; Array
#     ╎    ╎    ╎   1     ...m/src/misc.jl:222; shuffle!(r::MersenneTw...
#     ╎    ╎    ╎    1     ...src/Random.jl:225; rand
#     ╎    ╎    ╎     1     ...src/Random.jl:235; rand
#     ╎    ╎    ╎    ╎ 1     ...src/Random.jl:254; rand
#     ╎    ╎    ╎    ╎  1     ...eneration.jl:128; rand
#     ╎    ╎    ╎    ╎   1     ...rc/Random.jl:254; rand
#     ╎    ╎    ╎    ╎    1     ...src/RNGs.jl:399; rand
#     ╎    ╎    ╎    ╎     1     ...src/RNGs.jl:394; rand_inbounds
#     ╎    ╎    ╎    ╎    ╎ 1     ...src/RNGs.jl:390; rand_inbounds
#     ╎    ╎    ╎    ╎    ╎  1     ...rc/RNGs.jl:191; mt_pop!
#    1╎    ╎    ╎    ╎    ╎   1     @Base/Base.jl:38; getproperty
#     ╎    ╎    8     In[10]:52; scan_perms_threads(y::Mat...
#    8╎    ╎     8     @Base/boot.jl:461; Array
#     ╎    ╎    28    In[10]:58; scan_perms_threads(y::Mat...
#     ╎    ╎     28    ...ngconstructs.jl:89; macro expansion
#     ╎    ╎    ╎ 28    ...ngconstructs.jl:38; threading_run(fun::var"#...
#     ╎    ╎    ╎  28    @Base/task.jl:343; wait
#     ╎    ╎    ╎   28    @Base/task.jl:304; _wait(t::Task)
#     ╎    ╎    ╎    28    .../condition.jl:124; wait(c::Base.GenericCo...
#     ╎    ╎    ╎     28    @Base/task.jl:930; wait()
#   28╎    ╎    ╎    ╎ 28    @Base/task.jl:921; poptask(W::Base.Invas...
#     ╎    ╎    136   In[10]:65; scan_perms_threads(y::Mat...
#     ╎    ╎     19    @Base/arraymath.jl:21; *(A::Float64, B::Matrix{...
#     ╎    ╎    ╎ 19    @Base/broadcast.jl:849; broadcast_preserving_zero_d
#     ╎    ╎    ╎  19    ...e/broadcast.jl:860; materialize
#     ╎    ╎    ╎   19    ...e/broadcast.jl:885; copy
#     ╎    ╎    ╎    19    .../broadcast.jl:913; copyto!
#     ╎    ╎    ╎     19    .../broadcast.jl:960; copyto!
#     ╎    ╎    ╎    ╎ 19    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎  19    ...broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎     4     ...roadcast.jl:670; _broadcast_getinde...
#    4╎    ╎    ╎    ╎    ╎ 4     @Base/float.jl:385; *
#     ╎    ╎    ╎    ╎   15    ...mensional.jl:674; setindex!
#   15╎    ╎    ╎    ╎    15    @Base/array.jl:968; setindex!
#     ╎    ╎     117   @Base/broadcast.jl:860; materialize(bc::Base.Bro...
#     ╎    ╎    ╎ 117   @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  116   ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   116   ...e/broadcast.jl:960; copyto!
#     ╎    ╎    ╎    113   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     113   .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 106   .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  99    ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   99    ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    6     ...roadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎     6     ...roadcast.jl:667; _getindex
#     ╎    ╎    ╎    ╎    ╎ 6     ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎  6     ...nsional.jl:672; getindex
#    6╎    ╎    ╎    ╎    ╎   6     ...e/array.jl:925; getindex
#     ╎    ╎    ╎    ╎    93    ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎     93    ...roadcast.jl:670; _broadcast_getinde...
#    3╎    ╎    ╎    ╎    ╎ 93    ...cial/log.jl:268; log10
#   15╎    ╎    ╎    ╎    ╎  15    ...ial/log.jl:0; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:270; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:271; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:272; _log(x::Float64, ...
#    6╎    ╎    ╎    ╎    ╎  6     ...ial/log.jl:275; _log(x::Float64, ...
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:281; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...entials.jl:438; reinterpret
#     ╎    ╎    ╎    ╎    ╎  4     ...ial/log.jl:283; _log(x::Float64, ...
#    4╎    ╎    ╎    ╎    ╎   4     ...omotion.jl:477; ==
#     ╎    ╎    ╎    ╎    ╎  12    ...ial/log.jl:289; _log(x::Float64, ...
#    6╎    ╎    ╎    ╎    ╎   6     ...entials.jl:438; reinterpret
#    5╎    ╎    ╎    ╎    ╎   5     @Base/int.jl:340; &
#    1╎    ╎    ╎    ╎    ╎   1     @Base/int.jl:365; |
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:292; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:293; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    ╎    ╎    ╎  46    ...ial/log.jl:295; _log(x::Float64, ...
#     ╎    ╎    ╎    ╎    ╎   5     ...ial/log.jl:162; log_proc1
#    5╎    ╎    ╎    ╎    ╎    5     .../float.jl:310; unsafe_trunc
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:165; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     ...e/tuple.jl:29; getindex
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:166; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     .../float.jl:383; +
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:167; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:180; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   10    ...ial/log.jl:181; log_proc1
#   10╎    ╎    ╎    ╎    ╎    10    .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   5     ...ial/log.jl:182; log_proc1
#     ╎    ╎    ╎    ╎    ╎    5     ...rators.jl:591; *
#    5╎    ╎    ╎    ╎    ╎     5     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   18    ...ial/log.jl:189; log_proc1
#    7╎    ╎    ╎    ╎    ╎    7     .../float.jl:383; +
#     ╎    ╎    ╎    ╎    ╎    11    ...tfuncs.jl:422; fma
#   11╎    ╎    ╎    ╎    ╎     11    ...tfuncs.jl:417; fma_llvm
#     ╎    ╎    ╎    ╎  7     ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   7     ...broadcast.jl:670; _broadcast_getindex...
#    7╎    ╎    ╎    ╎    7     @Base/float.jl:384; -
#     ╎    ╎    ╎    ╎ 7     ...imensional.jl:674; setindex!
#    7╎    ╎    ╎    ╎  7     @Base/array.jl:968; setindex!
#     ╎    ╎    ╎    3     @Base/simdloop.jl:78; macro expansion
#    3╎    ╎    ╎     3     @Base/int.jl:87; +
#     ╎    ╎    ╎  1     ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎   1     ...e/broadcast.jl:212; similar
#     ╎    ╎    ╎    1     ...tractarray.jl:840; similar
#     ╎    ╎    ╎     1     ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎ 1     @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎  1     @Base/boot.jl:469; Array
#    1╎    ╎    ╎    ╎   1     @Base/boot.jl:461; Array
#     ╎    ╎   101   In[37]:1; (::var"#scan_perms_threads#...
#     ╎    ╎    6     In[37]:18; scan_perms_threads(y::Mat...
#     ╎    ╎     2     ...M.jl/src/lmm.jl:44; rotateData
#     ╎    ╎    ╎ 2     ...ra/src/eigen.jl:235; eigen
#     ╎    ╎    ╎  2     ...a/src/eigen.jl:238; eigen(A::Matrix{Float64...
#     ╎    ╎    ╎   2     ...a/src/eigen.jl:149; eigen!##kw
#     ╎    ╎    ╎    2     .../src/eigen.jl:152; eigen!(A::Matrix{Float...
#     ╎    ╎    ╎     2     ...metriceigen.jl:4; eigen!##kw
#     ╎    ╎    ╎    ╎ 2     ...etriceigen.jl:4; #eigen!#211
#    2╎    ╎    ╎    ╎  2     ...rc/lapack.jl:5102; syevr!(jobz::Char, ...
#     ╎    ╎     4     ...M.jl/src/lmm.jl:47; rotateData
#     ╎    ╎    ╎ 4     ...a/src/matmul.jl:148; *
#     ╎    ╎    ╎  4     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎   4     .../src/matmul.jl:425; mul!
#     ╎    ╎    ╎    4     ...src/matmul.jl:378; mul!
#     ╎    ╎    ╎     4     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    4╎    ╎    ╎    ╎ 4     .../src/blas.jl:1514; gemm!(transA::Char, ...
#     ╎    ╎    1     In[37]:34; scan_perms_threads(y::Mat...
#     ╎    ╎     1     ....jl/src/util.jl:123; rowMultiply!(A::Matrix{F...
#    1╎    ╎    ╎ 1     @Base/float.jl:385; *
#     ╎    ╎    6     In[37]:38; scan_perms_threads(y::Mat...
#     ╎    ╎     6     ...M.jl/src/wls.jl:167; resid
#     ╎    ╎    ╎ 1     ...M.jl/src/wls.jl:172; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  1     .../src/matmul.jl:148; *
#     ╎    ╎    ╎   1     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎    1     ...src/matmul.jl:425; mul!
#     ╎    ╎    ╎     1     ...src/matmul.jl:378; mul!
#     ╎    ╎    ╎    ╎ 1     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    1╎    ╎    ╎    ╎  1     .../src/blas.jl:1514; gemm!(transA::Char,...
#     ╎    ╎    ╎ 4     ...M.jl/src/wls.jl:182; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  4     .../src/matmul.jl:148; *
#     ╎    ╎    ╎   4     .../src/matmul.jl:276; mul!
#     ╎    ╎    ╎    4     ...src/matmul.jl:161; mul!
#     ╎    ╎    ╎     4     ...src/matmul.jl:674; gemm_wrapper!(C::Matr...
#    4╎    ╎    ╎    ╎ 4     .../src/blas.jl:1514; gemm!(transA::Char, ...
#     ╎    ╎    ╎ 1     ...M.jl/src/wls.jl:183; resid(y::Matrix{Float64}...
#     ╎    ╎    ╎  1     @Base/arraymath.jl:8; -(A::Matrix{Float64}, B:...
#     ╎    ╎    ╎   1     ...e/broadcast.jl:849; broadcast_preserving_z...
#     ╎    ╎    ╎    1     .../broadcast.jl:860; materialize
#     ╎    ╎    ╎     1     .../broadcast.jl:885; copy
#     ╎    ╎    ╎    ╎ 1     .../broadcast.jl:913; copyto!
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:960; copyto!
#     ╎    ╎    ╎    ╎   1     .../simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎     1     ...roadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:670; _broadcast_getind...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    1     In[37]:43; scan_perms_threads(y::Mat...
#     ╎    ╎     1     ....jl/src/util.jl:152; shuffleVector##kw
#     ╎    ╎    ╎ 1     ....jl/src/util.jl:165; shuffleVector(rng::Merse...
#     ╎    ╎    ╎  1     ...stractarray.jl:1344; setindex!
#     ╎    ╎    ╎   1     ...dimensional.jl:930; _setindex!
#     ╎    ╎    ╎    1     ...imensional.jl:941; _unsafe_setindex!(::In...
#     ╎    ╎    ╎     1     .../cartesian.jl:64; macro expansion
#     ╎    ╎    ╎    ╎ 1     ...imensional.jl:947; macro expansion
#     ╎    ╎    ╎    ╎  1     @Base/array.jl:898; iterate
#     ╎    ╎    ╎    ╎   1     @Base/int.jl:991; -
#    1╎    ╎    ╎    ╎    1     @Base/int.jl:86; -
#     ╎    ╎    9     In[37]:58; scan_perms_threads(y::Mat...
#     ╎    ╎     9     ...ngconstructs.jl:89; macro expansion
#     ╎    ╎    ╎ 9     ...ngconstructs.jl:38; threading_run(fun::var"#...
#     ╎    ╎    ╎  9     @Base/task.jl:343; wait
#     ╎    ╎    ╎   9     @Base/task.jl:304; _wait(t::Task)
#     ╎    ╎    ╎    9     .../condition.jl:124; wait(c::Base.GenericCo...
#     ╎    ╎    ╎     9     @Base/task.jl:930; wait()
#    9╎    ╎    ╎    ╎ 9     @Base/task.jl:921; poptask(W::Base.Invas...
#     ╎    ╎    78    In[37]:65; scan_perms_threads(y::Mat...
#     ╎    ╎     10    @Base/arraymath.jl:21; *(A::Float64, B::Matrix{...
#     ╎    ╎    ╎ 10    @Base/broadcast.jl:849; broadcast_preserving_zero_d
#     ╎    ╎    ╎  10    ...e/broadcast.jl:860; materialize
#     ╎    ╎    ╎   10    ...e/broadcast.jl:885; copy
#     ╎    ╎    ╎    10    .../broadcast.jl:913; copyto!
#     ╎    ╎    ╎     10    .../broadcast.jl:960; copyto!
#     ╎    ╎    ╎    ╎ 10    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎  10    ...broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎   5     ...broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎    5     ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎     5     ...roadcast.jl:670; _broadcast_getinde...
#    5╎    ╎    ╎    ╎    ╎ 5     @Base/float.jl:385; *
#     ╎    ╎    ╎    ╎   5     ...mensional.jl:674; setindex!
#    5╎    ╎    ╎    ╎    5     @Base/array.jl:968; setindex!
#     ╎    ╎     68    @Base/broadcast.jl:860; materialize(bc::Base.Bro...
#     ╎    ╎    ╎ 68    @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  68    ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   68    ...e/broadcast.jl:960; copyto!
#     ╎    ╎    ╎    68    @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     68    .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 68    .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  67    ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   67    ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎     1     ...roadcast.jl:667; _getindex
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎    ╎  1     ...nsional.jl:672; getindex
#    1╎    ╎    ╎    ╎    ╎   1     ...e/array.jl:925; getindex
#     ╎    ╎    ╎    ╎    66    ...roadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎     66    ...roadcast.jl:670; _broadcast_getinde...
#    5╎    ╎    ╎    ╎    ╎ 66    ...cial/log.jl:268; log10
#   12╎    ╎    ╎    ╎    ╎  12    ...ial/log.jl:0; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:270; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:271; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:272; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:275; _log(x::Float64, ...
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:281; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...entials.jl:438; reinterpret
#     ╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:283; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎   2     ...omotion.jl:477; ==
#     ╎    ╎    ╎    ╎    ╎  2     ...ial/log.jl:288; _log(x::Float64, ...
#    2╎    ╎    ╎    ╎    ╎   2     @Base/int.jl:86; -
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:289; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...entials.jl:438; reinterpret
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:292; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    ╎    ╎    ╎  1     ...ial/log.jl:293; _log(x::Float64, ...
#    1╎    ╎    ╎    ╎    ╎   1     ...e/float.jl:384; -
#     ╎    ╎    ╎    ╎    ╎  34    ...ial/log.jl:295; _log(x::Float64, ...
#     ╎    ╎    ╎    ╎    ╎   3     ...ial/log.jl:162; log_proc1
#    3╎    ╎    ╎    ╎    ╎    3     .../float.jl:310; unsafe_trunc
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:166; log_proc1
#    2╎    ╎    ╎    ╎    ╎    2     .../float.jl:383; +
#     ╎    ╎    ╎    ╎    ╎   5     ...ial/log.jl:181; log_proc1
#    5╎    ╎    ╎    ╎    ╎    5     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   2     ...ial/log.jl:182; log_proc1
#     ╎    ╎    ╎    ╎    ╎    2     ...rators.jl:591; *
#    2╎    ╎    ╎    ╎    ╎     2     .../float.jl:385; *
#     ╎    ╎    ╎    ╎    ╎   22    ...ial/log.jl:189; log_proc1
#   12╎    ╎    ╎    ╎    ╎    12    .../float.jl:383; +
#     ╎    ╎    ╎    ╎    ╎    10    ...tfuncs.jl:422; fma
#   10╎    ╎    ╎    ╎    ╎     10    ...tfuncs.jl:417; fma_llvm
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   1     ...broadcast.jl:670; _broadcast_getindex...
#    1╎    ╎    ╎    ╎    1     @Base/float.jl:384; -
#     ╎68    @Base/task.jl:134; (::Base.var"#666#667"{typeof(I...
#     ╎ 68    @Base/asyncevent.jl:279; macro expansion
#     ╎  66    @Base/asyncevent.jl:138; _trywait(t::Timer)
#     ╎   66    @Base/condition.jl:124; wait(c::Base.GenericConditio...
#     ╎    66    @Base/task.jl:930; wait()
#   66╎     66    @Base/task.jl:921; poptask(W::Base.InvasiveLin...
#     ╎  2     @Base/asyncevent.jl:140; _trywait(t::Timer)
#    2╎   2     @Base/libuv.jl:48; iolock_begin
#     ╎6161  @Base/task.jl:634; task_done_hook(t::Task)
#     ╎ 6161  @Base/task.jl:930; wait()
# 6160╎  6161  @Base/task.jl:921; poptask(W::Base.InvasiveLinke...
#     ╎3938  ...eadingconstructs.jl:30; (::Base.Threads.var"#1#2"{var"...
#    1╎ 1463  ...eadingconstructs.jl:51; #103#threadsfor_fun
#     ╎  1462  ...eadingconstructs.jl:84; (::var"#103#threadsfor_fun#92"...
#    2╎   1462  In[37]:61; macro expansion
#     ╎    2     .../abstractarray.jl:1344; setindex!(::Matrix{Float64}...
#     ╎     2     ...ltidimensional.jl:930; _setindex!
#     ╎    ╎ 2     ...ltidimensional.jl:941; _unsafe_setindex!(::IndexLi...
#     ╎    ╎  2     @Base/cartesian.jl:64; macro expansion
#     ╎    ╎   1     ...tidimensional.jl:946; macro expansion
#    1╎    ╎    1     @Base/array.jl:968; setindex!
#     ╎    ╎   1     ...tidimensional.jl:947; macro expansion
#     ╎    ╎    1     @Base/array.jl:898; iterate
#    1╎    ╎     1     @Base/int.jl:87; +
#     ╎    1458  ...LMM.jl/src/wls.jl:146; rss
#     ╎     1047  ...LMM.jl/src/wls.jl:148; rss(y::Matrix{Float64}, X::...
#    1╎    ╎ 1047  ...LMM.jl/src/wls.jl:189; resid##kw
#     ╎    ╎  1     ...MM.jl/src/wls.jl:193; resid(y::Matrix{Float64}, ...
#     ╎    ╎   1     ...trings/string.jl:125; ==(a::String, b::String)
#     ╎    ╎    1     ...rings/string.jl:113; _memcmp
#    1╎    ╎     1     @Base/pointer.jl:59; unsafe_convert
#     ╎    ╎  638   ...MM.jl/src/wls.jl:194; resid(y::Matrix{Float64}, ...
#     ╎    ╎   8     @Base/arraymath.jl:21; \
#     ╎    ╎    8     ...src/adjtrans.jl:252; broadcast_preserving_zero_d
#     ╎    ╎     8     @Base/broadcast.jl:798; broadcast(::LinearAlgebr...
#     ╎    ╎    ╎ 8     @Base/broadcast.jl:860; materialize
#     ╎    ╎    ╎  8     ...e/broadcast.jl:885; copy
#     ╎    ╎    ╎   4     ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎    4     .../broadcast.jl:960; copyto!
#     ╎    ╎    ╎     4     ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:961; macro expansion
#    4╎    ╎    ╎    ╎  4     @Base/array.jl:966; setindex!
#     ╎    ╎    ╎   4     ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎    4     .../broadcast.jl:212; similar
#     ╎    ╎    ╎     4     ...tractarray.jl:840; similar
#     ╎    ╎    ╎    ╎ 4     ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎  4     @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎   4     @Base/boot.jl:468; Array
#    4╎    ╎    ╎    ╎    4     @Base/boot.jl:459; Array
#     ╎    ╎   630   ...ra/src/matmul.jl:119; *
#     ╎    ╎    630   ...a/src/matmul.jl:101; *
#     ╎    ╎     3     ...bstractarray.jl:797; similar
#     ╎    ╎    ╎ 3     @Base/subarray.jl:65; similar
#     ╎    ╎    ╎  3     @Base/array.jl:378; similar
#     ╎    ╎    ╎   3     @Base/boot.jl:468; Array
#    3╎    ╎    ╎    3     @Base/boot.jl:459; Array
#     ╎    ╎     627   ...a/src/matmul.jl:276; mul!
#     ╎    ╎    ╎ 627   ...a/src/matmul.jl:109; mul!
#     ╎    ╎    ╎  627   ...a/src/matmul.jl:93; mul!
#     ╎    ╎    ╎   627   .../src/matmul.jl:503; gemv!(y::Vector{Float6...
#  627╎    ╎    ╎    627   ...a/src/blas.jl:666; gemv!(trans::Char, alp...
#     ╎    ╎  198   ...MM.jl/src/wls.jl:204; resid(y::Matrix{Float64}, ...
#     ╎    ╎   198   .../src/adjtrans.jl:301; *
#     ╎    ╎    198   @Base/broadcast.jl:798; broadcast(::typeof(*), ::...
#     ╎    ╎     198   @Base/broadcast.jl:860; materialize
#     ╎    ╎    ╎ 198   @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  175   ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   1     ...e/broadcast.jl:957; copyto!
#     ╎    ╎    ╎    1     .../broadcast.jl:940; preprocess
#     ╎    ╎    ╎     1     .../broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎    ╎ 1     .../broadcast.jl:944; preprocess_args
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:941; preprocess
#     ╎    ╎    ╎    ╎   1     ...broadcast.jl:637; extrude
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎     1     ...roadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:591; _newindexer
#     ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎   1     ...erators.jl:282; !=
#    1╎    ╎    ╎    ╎    ╎    1     ...motion.jl:477; ==
#     ╎    ╎    ╎   174   ...e/broadcast.jl:960; copyto!
#    3╎    ╎    ╎    5     @Base/simdloop.jl:75; macro expansion
#    2╎    ╎    ╎     2     @Base/int.jl:83; <
#     ╎    ╎    ╎    34    @Base/simdloop.jl:76; macro expansion
#     ╎    ╎    ╎     34    ...imensional.jl:480; simd_index
#   34╎    ╎    ╎    ╎ 34    @Base/int.jl:87; +
#     ╎    ╎    ╎    135   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     135   .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 19    .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  8     ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   8     ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    8     ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎     8     ...actarray.jl:1241; getindex
#     ╎    ╎    ╎    ╎    ╎ 8     ...ctarray.jl:1269; _getindex
#     ╎    ╎    ╎    ╎    ╎  8     ...ubarray.jl:315; getindex
#    8╎    ╎    ╎    ╎    ╎   8     ...e/array.jl:924; getindex
#     ╎    ╎    ╎    ╎  11    ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   11    ...broadcast.jl:670; _broadcast_getindex...
#   11╎    ╎    ╎    ╎    11    @Base/float.jl:385; *
#     ╎    ╎    ╎    ╎ 116   ...imensional.jl:674; setindex!
#  116╎    ╎    ╎    ╎  116   @Base/array.jl:968; setindex!
#     ╎    ╎    ╎  23    ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎   23    ...e/broadcast.jl:212; similar
#     ╎    ╎    ╎    23    ...tractarray.jl:840; similar
#     ╎    ╎    ╎     23    ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎ 23    @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎  23    @Base/boot.jl:469; Array
#   23╎    ╎    ╎    ╎   23    @Base/boot.jl:461; Array
#     ╎    ╎  209   ...MM.jl/src/wls.jl:205; resid(y::Matrix{Float64}, ...
#     ╎    ╎   209   @Base/arraymath.jl:8; -(A::Matrix{Float64}, B::Ma...
#     ╎    ╎    209   @Base/broadcast.jl:849; broadcast_preserving_zero_d
#     ╎    ╎     209   @Base/broadcast.jl:860; materialize
#     ╎    ╎    ╎ 209   @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  204   ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   3     ...e/broadcast.jl:957; copyto!
#     ╎    ╎    ╎    3     .../broadcast.jl:940; preprocess
#     ╎    ╎    ╎     3     .../broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎    ╎ 1     .../broadcast.jl:941; preprocess
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:637; extrude
#     ╎    ╎    ╎    ╎   1     ...broadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎     1     ...roadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎ 1     ...perators.jl:282; !=
#    1╎    ╎    ╎    ╎    ╎  1     ...omotion.jl:477; ==
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:944; preprocess_args
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:941; preprocess
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:637; extrude
#     ╎    ╎    ╎    ╎    2     ...roadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:591; _newindexer
#     ╎    ╎    ╎    ╎    ╎  1     ...oadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎   1     ...erators.jl:282; !=
#    1╎    ╎    ╎    ╎    ╎    1     ...motion.jl:477; ==
#     ╎    ╎    ╎    ╎    ╎ 1     ...roadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎  1     ...erators.jl:282; !=
#    1╎    ╎    ╎    ╎    ╎   1     ...omotion.jl:477; ==
#     ╎    ╎    ╎   201   ...e/broadcast.jl:960; copyto!
#    2╎    ╎    ╎    2     @Base/simdloop.jl:0; macro expansion
#    5╎    ╎    ╎    5     @Base/simdloop.jl:75; macro expansion
#     ╎    ╎    ╎    189   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     189   .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 90    .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  38    ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   38    ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    38    ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎     38    ...ensional.jl:672; getindex
#   38╎    ╎    ╎    ╎    ╎ 38    @Base/array.jl:925; getindex
#     ╎    ╎    ╎    ╎  52    ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   52    ...broadcast.jl:670; _broadcast_getindex...
#   52╎    ╎    ╎    ╎    52    @Base/float.jl:384; -
#     ╎    ╎    ╎    ╎ 99    ...imensional.jl:674; setindex!
#   99╎    ╎    ╎    ╎  99    @Base/array.jl:968; setindex!
#     ╎    ╎    ╎    5     @Base/simdloop.jl:78; macro expansion
#    5╎    ╎    ╎     5     @Base/int.jl:87; +
#     ╎    ╎    ╎  5     ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎   5     ...e/broadcast.jl:212; similar
#     ╎    ╎    ╎    5     ...tractarray.jl:840; similar
#     ╎    ╎    ╎     5     ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎ 5     @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎  5     @Base/boot.jl:469; Array
#    5╎    ╎    ╎    ╎   5     @Base/boot.jl:461; Array
#     ╎     411   ...LMM.jl/src/wls.jl:149; rss(y::Matrix{Float64}, X::...
#     ╎    ╎ 348   @Base/broadcast.jl:860; materialize
#     ╎    ╎  348   @Base/broadcast.jl:885; copy
#     ╎    ╎   179   @Base/broadcast.jl:913; copyto!
#     ╎    ╎    3     @Base/broadcast.jl:957; copyto!
#     ╎    ╎     3     @Base/broadcast.jl:940; preprocess
#     ╎    ╎    ╎ 3     @Base/broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎  3     ...e/broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎   3     ...e/broadcast.jl:941; preprocess
#     ╎    ╎    ╎    3     .../broadcast.jl:637; extrude
#     ╎    ╎    ╎     3     .../broadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎ 3     .../broadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎  3     ...broadcast.jl:591; _newindexer
#     ╎    ╎    ╎    ╎   3     ...broadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    3     ...perators.jl:282; !=
#    3╎    ╎    ╎    ╎     3     ...romotion.jl:477; ==
#     ╎    ╎    176   @Base/broadcast.jl:960; copyto!
#    7╎    ╎     8     @Base/simdloop.jl:75; macro expansion
#    1╎    ╎    ╎ 1     @Base/int.jl:83; <
#     ╎    ╎     162   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎ 162   @Base/broadcast.jl:961; macro expansion
#     ╎    ╎    ╎  107   ...e/broadcast.jl:597; getindex
#     ╎    ╎    ╎   69    ...e/broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    69    .../broadcast.jl:666; _getindex
#     ╎    ╎    ╎     69    .../broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎ 69    .../broadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎  69    ...mensional.jl:672; getindex
#   69╎    ╎    ╎    ╎   69    @Base/array.jl:925; getindex
#     ╎    ╎    ╎   38    ...e/broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    38    .../broadcast.jl:670; _broadcast_getindex_evalf
#     ╎    ╎    ╎     38    ...e/intfuncs.jl:321; literal_pow
#   38╎    ╎    ╎    ╎ 38    @Base/float.jl:385; *
#     ╎    ╎    ╎  55    ...dimensional.jl:674; setindex!
#   55╎    ╎    ╎   55    @Base/array.jl:968; setindex!
#     ╎    ╎     6     @Base/simdloop.jl:78; macro expansion
#    6╎    ╎    ╎ 6     @Base/int.jl:87; +
#     ╎    ╎   169   @Base/broadcast.jl:211; similar
#     ╎    ╎    169   @Base/broadcast.jl:212; similar
#     ╎    ╎     169   ...bstractarray.jl:840; similar
#     ╎    ╎    ╎ 169   ...bstractarray.jl:841; similar
#     ╎    ╎    ╎  169   @Base/boot.jl:476; Array
#     ╎    ╎    ╎   169   @Base/boot.jl:469; Array
#  169╎    ╎    ╎    169   @Base/boot.jl:461; Array
#     ╎    ╎ 63    @Base/reducedim.jl:406; reduce##kw
#     ╎    ╎  63    @Base/reducedim.jl:406; #reduce#767
#     ╎    ╎   63    @Base/reducedim.jl:357; mapreduce##kw
#     ╎    ╎    63    @Base/reducedim.jl:357; #mapreduce#765
#     ╎    ╎     63    @Base/reducedim.jl:371; _mapreduce_dim
#     ╎    ╎    ╎ 61    @Base/reducedim.jl:324; mapreducedim!
#     ╎    ╎    ╎  61    ...e/reducedim.jl:295; _mapreducedim!(f::typeo...
#    1╎    ╎    ╎   1     @Base/array.jl:966; setindex!
#    1╎    ╎    ╎   60    @Base/reduce.jl:272; mapreduce_impl
#     ╎    ╎    ╎    59    @Base/reduce.jl:258; mapreduce_impl(f::type...
#   10╎    ╎    ╎     27    ...e/simdloop.jl:75; macro expansion
#   17╎    ╎    ╎    ╎ 17    @Base/int.jl:83; <
#     ╎    ╎    ╎     25    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎ 25    @Base/reduce.jl:260; macro expansion
#   25╎    ╎    ╎    ╎  25    @Base/float.jl:383; +
#     ╎    ╎    ╎     7     ...e/simdloop.jl:78; macro expansion
#    7╎    ╎    ╎    ╎ 7     @Base/int.jl:87; +
#     ╎    ╎    ╎ 2     @Base/reducedim.jl:219; reducedim_init
#     ╎    ╎    ╎  2     @Base/reducedim.jl:92; reducedim_initarray
#     ╎    ╎    ╎   2     ...e/reducedim.jl:91; reducedim_initarray(A::...
#     ╎    ╎    ╎    2     ...tractarray.jl:803; similar
#     ╎    ╎    ╎     2     @Base/array.jl:378; similar
#     ╎    ╎    ╎    ╎ 2     @Base/boot.jl:469; Array
#    2╎    ╎    ╎    ╎  2     @Base/boot.jl:461; Array
#     ╎ 2475  ...eadingconstructs.jl:51; #49#threadsfor_fun
#     ╎  2475  ...eadingconstructs.jl:84; (::var"#49#threadsfor_fun#42"{...
#     ╎   2475  In[10]:61; macro expansion
#    1╎    1     .../abstractarray.jl:1341; setindex!(::Matrix{Float64}...
#     ╎    57    .../abstractarray.jl:1344; setindex!(::Matrix{Float64}...
#     ╎     57    ...ltidimensional.jl:930; _setindex!
#     ╎    ╎ 57    ...ltidimensional.jl:941; _unsafe_setindex!(::IndexLi...
#     ╎    ╎  56    @Base/cartesian.jl:64; macro expansion
#    1╎    ╎   1     ...tidimensional.jl:944; macro expansion
#     ╎    ╎   49    ...tidimensional.jl:946; macro expansion
#   49╎    ╎    49    @Base/array.jl:968; setindex!
#     ╎    ╎   6     ...tidimensional.jl:947; macro expansion
#     ╎    ╎    6     @Base/array.jl:898; iterate
#    1╎    ╎     1     @Base/array.jl:924; getindex
#    3╎    ╎     3     @Base/int.jl:87; +
#     ╎    ╎     1     @Base/int.jl:991; -
#    1╎    ╎    ╎ 1     @Base/int.jl:86; -
#     ╎    ╎     1     @Base/int.jl:487; <
#    1╎    ╎    ╎ 1     @Base/int.jl:480; <
#     ╎    ╎  1     @Base/cartesian.jl:66; macro expansion
#     ╎    ╎   1     @Base/indices.jl:367; iterate
#     ╎    ╎    1     @Base/range.jl:883; iterate
#    1╎    ╎     1     @Base/promotion.jl:477; ==
#     ╎    2417  ...LMM.jl/src/wls.jl:146; rss
#     ╎     1792  ...LMM.jl/src/wls.jl:148; rss(y::Matrix{Float64}, X::...
#     ╎    ╎ 1792  ...LMM.jl/src/wls.jl:189; resid##kw
#    1╎    ╎  1     ...ebra/src/blas.jl:387; dot(x::SubArray{Float64, 1...
#     ╎    ╎  614   ...MM.jl/src/wls.jl:194; resid(y::Matrix{Float64}, ...
#     ╎    ╎   48    @Base/arraymath.jl:21; \
#     ╎    ╎    48    ...src/adjtrans.jl:252; broadcast_preserving_zero_d
#     ╎    ╎     48    @Base/broadcast.jl:798; broadcast(::LinearAlgebr...
#     ╎    ╎    ╎ 48    @Base/broadcast.jl:860; materialize
#     ╎    ╎    ╎  48    ...e/broadcast.jl:885; copy
#     ╎    ╎    ╎   23    ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎    23    .../broadcast.jl:960; copyto!
#     ╎    ╎    ╎     23    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎ 23    .../broadcast.jl:961; macro expansion
#   22╎    ╎    ╎    ╎  22    @Base/array.jl:966; setindex!
#     ╎    ╎    ╎    ╎  1     ...broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎   1     ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎    1     ...roadcast.jl:670; _broadcast_getindex...
#     ╎    ╎    ╎    ╎     1     ...adjtrans.jl:252; #9
#     ╎    ╎    ╎    ╎    ╎ 1     ...perators.jl:629; \
#    1╎    ╎    ╎    ╎    ╎  1     ...e/float.jl:386; /
#     ╎    ╎    ╎   25    ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎    25    .../broadcast.jl:212; similar
#     ╎    ╎    ╎     25    ...tractarray.jl:840; similar
#     ╎    ╎    ╎    ╎ 25    ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎  25    @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎   25    @Base/boot.jl:468; Array
#   25╎    ╎    ╎    ╎    25    @Base/boot.jl:459; Array
#     ╎    ╎   5     .../src/adjtrans.jl:295; *
#     ╎    ╎    5     ...ra/src/matmul.jl:14; dot
#     ╎    ╎     5     ...bra/src/blas.jl:390; dot(x::SubArray{Float64,...
#    5╎    ╎    ╎ 5     ...bra/src/blas.jl:340; dot
#     ╎    ╎   561   ...ra/src/matmul.jl:119; *
#     ╎    ╎    561   ...a/src/matmul.jl:101; *
#     ╎    ╎     9     ...bstractarray.jl:797; similar
#     ╎    ╎    ╎ 9     @Base/subarray.jl:65; similar
#     ╎    ╎    ╎  9     @Base/array.jl:378; similar
#     ╎    ╎    ╎   9     @Base/boot.jl:468; Array
#    9╎    ╎    ╎    9     @Base/boot.jl:459; Array
#     ╎    ╎     552   ...a/src/matmul.jl:276; mul!
#     ╎    ╎    ╎ 552   ...a/src/matmul.jl:109; mul!
#     ╎    ╎    ╎  552   ...a/src/matmul.jl:93; mul!
#     ╎    ╎    ╎   552   .../src/matmul.jl:503; gemv!(y::Vector{Float6...
#  552╎    ╎    ╎    552   ...a/src/blas.jl:666; gemv!(trans::Char, alp...
#     ╎    ╎  568   ...MM.jl/src/wls.jl:204; resid(y::Matrix{Float64}, ...
#     ╎    ╎   568   .../src/adjtrans.jl:301; *
#    1╎    ╎    568   @Base/broadcast.jl:798; broadcast(::typeof(*), ::...
#     ╎    ╎     567   @Base/broadcast.jl:860; materialize
#     ╎    ╎    ╎ 567   @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  503   ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   4     ...e/broadcast.jl:957; copyto!
#     ╎    ╎    ╎    4     .../broadcast.jl:940; preprocess
#     ╎    ╎    ╎     4     .../broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:944; preprocess_args
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:941; preprocess
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:637; extrude
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎     4     ...roadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎    ╎ 4     ...roadcast.jl:591; _newindexer
#     ╎    ╎    ╎    ╎    ╎  4     ...oadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎   4     ...erators.jl:282; !=
#    4╎    ╎    ╎    ╎    ╎    4     ...motion.jl:477; ==
#     ╎    ╎    ╎   497   ...e/broadcast.jl:960; copyto!
#    2╎    ╎    ╎    2     @Base/simdloop.jl:0; macro expansion
#    5╎    ╎    ╎    7     @Base/simdloop.jl:75; macro expansion
#    2╎    ╎    ╎     2     @Base/int.jl:83; <
#     ╎    ╎    ╎    71    @Base/simdloop.jl:76; macro expansion
#     ╎    ╎    ╎     71    ...imensional.jl:480; simd_index
#   71╎    ╎    ╎    ╎ 71    @Base/int.jl:87; +
#     ╎    ╎    ╎    412   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     412   .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 25    .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  11    ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   11    ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    11    ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎     11    ...actarray.jl:1241; getindex
#     ╎    ╎    ╎    ╎    ╎ 11    ...ctarray.jl:1269; _getindex
#     ╎    ╎    ╎    ╎    ╎  11    ...ubarray.jl:315; getindex
#   11╎    ╎    ╎    ╎    ╎   11    ...e/array.jl:924; getindex
#     ╎    ╎    ╎    ╎  14    ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   14    ...broadcast.jl:670; _broadcast_getindex...
#   14╎    ╎    ╎    ╎    14    @Base/float.jl:385; *
#     ╎    ╎    ╎    ╎ 387   ...imensional.jl:674; setindex!
#  387╎    ╎    ╎    ╎  387   @Base/array.jl:968; setindex!
#    4╎    ╎    ╎    5     @Base/simdloop.jl:84; macro expansion
#     ╎    ╎    ╎     1     ...imensional.jl:404; iterate
#     ╎    ╎    ╎    ╎ 1     ...imensional.jl:422; __inc
#    1╎    ╎    ╎    ╎  1     @Base/int.jl:87; +
#    2╎    ╎    ╎   2     @Base/simdloop.jl:0; copyto!
#     ╎    ╎    ╎  64    ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎   64    ...e/broadcast.jl:212; similar
#     ╎    ╎    ╎    64    ...tractarray.jl:840; similar
#     ╎    ╎    ╎     64    ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎ 64    @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎  64    @Base/boot.jl:469; Array
#   64╎    ╎    ╎    ╎   64    @Base/boot.jl:461; Array
#     ╎    ╎  609   ...MM.jl/src/wls.jl:205; resid(y::Matrix{Float64}, ...
#    1╎    ╎   1     @Base/arraymath.jl:7; -(A::Matrix{Float64}, B::Ma...
#     ╎    ╎   608   @Base/arraymath.jl:8; -(A::Matrix{Float64}, B::Ma...
#     ╎    ╎    608   @Base/broadcast.jl:849; broadcast_preserving_zero_d
#     ╎    ╎     608   @Base/broadcast.jl:860; materialize
#     ╎    ╎    ╎ 608   @Base/broadcast.jl:885; copy
#     ╎    ╎    ╎  557   ...e/broadcast.jl:913; copyto!
#     ╎    ╎    ╎   4     ...e/broadcast.jl:957; copyto!
#     ╎    ╎    ╎    4     .../broadcast.jl:940; preprocess
#     ╎    ╎    ╎     4     .../broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎    ╎ 4     .../broadcast.jl:941; preprocess
#     ╎    ╎    ╎    ╎  4     ...broadcast.jl:637; extrude
#     ╎    ╎    ╎    ╎   4     ...broadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎    4     ...roadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:591; _newindexer
#     ╎    ╎    ╎    ╎    ╎ 2     ...roadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎  2     ...erators.jl:282; !=
#    2╎    ╎    ╎    ╎    ╎   2     ...omotion.jl:477; ==
#     ╎    ╎    ╎    ╎     2     ...roadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    ╎ 2     ...perators.jl:282; !=
#    2╎    ╎    ╎    ╎    ╎  2     ...omotion.jl:477; ==
#     ╎    ╎    ╎   553   ...e/broadcast.jl:960; copyto!
#    3╎    ╎    ╎    3     @Base/simdloop.jl:0; macro expansion
#    9╎    ╎    ╎    11    @Base/simdloop.jl:75; macro expansion
#    2╎    ╎    ╎     2     @Base/int.jl:83; <
#     ╎    ╎    ╎    527   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎     527   .../broadcast.jl:961; macro expansion
#     ╎    ╎    ╎    ╎ 164   .../broadcast.jl:597; getindex
#     ╎    ╎    ╎    ╎  72    ...broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    ╎   72    ...broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎    72    ...roadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎     72    ...ensional.jl:672; getindex
#   72╎    ╎    ╎    ╎    ╎ 72    @Base/array.jl:925; getindex
#     ╎    ╎    ╎    ╎  92    ...broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    ╎   92    ...broadcast.jl:670; _broadcast_getindex...
#   92╎    ╎    ╎    ╎    92    @Base/float.jl:384; -
#     ╎    ╎    ╎    ╎ 363   ...imensional.jl:674; setindex!
#  363╎    ╎    ╎    ╎  363   @Base/array.jl:968; setindex!
#     ╎    ╎    ╎    10    @Base/simdloop.jl:78; macro expansion
#   10╎    ╎    ╎     10    @Base/int.jl:87; +
#     ╎    ╎    ╎    2     @Base/simdloop.jl:84; macro expansion
#     ╎    ╎    ╎     2     ...imensional.jl:404; iterate
#    2╎    ╎    ╎    ╎ 2     ...imensional.jl:423; __inc
#     ╎    ╎    ╎  51    ...e/broadcast.jl:211; similar
#     ╎    ╎    ╎   51    ...e/broadcast.jl:212; similar
#     ╎    ╎    ╎    51    ...tractarray.jl:840; similar
#     ╎    ╎    ╎     51    ...tractarray.jl:841; similar
#     ╎    ╎    ╎    ╎ 51    @Base/boot.jl:476; Array
#     ╎    ╎    ╎    ╎  51    @Base/boot.jl:469; Array
#   51╎    ╎    ╎    ╎   51    @Base/boot.jl:461; Array
#     ╎     625   ...LMM.jl/src/wls.jl:149; rss(y::Matrix{Float64}, X::...
#     ╎    ╎ 510   @Base/broadcast.jl:860; materialize
#     ╎    ╎  510   @Base/broadcast.jl:885; copy
#     ╎    ╎   448   @Base/broadcast.jl:913; copyto!
#     ╎    ╎    2     @Base/broadcast.jl:957; copyto!
#     ╎    ╎     2     @Base/broadcast.jl:940; preprocess
#     ╎    ╎    ╎ 2     @Base/broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎  2     ...e/broadcast.jl:943; preprocess_args
#     ╎    ╎    ╎   2     ...e/broadcast.jl:941; preprocess
#     ╎    ╎    ╎    2     .../broadcast.jl:637; extrude
#     ╎    ╎    ╎     2     .../broadcast.jl:586; newindexer
#     ╎    ╎    ╎    ╎ 2     .../broadcast.jl:587; shapeindexer
#     ╎    ╎    ╎    ╎  2     ...broadcast.jl:591; _newindexer
#     ╎    ╎    ╎    ╎   2     ...broadcast.jl:592; _newindexer
#     ╎    ╎    ╎    ╎    2     ...perators.jl:282; !=
#    2╎    ╎    ╎    ╎     2     ...romotion.jl:477; ==
#     ╎    ╎    446   @Base/broadcast.jl:960; copyto!
#    3╎    ╎     3     @Base/simdloop.jl:75; macro expansion
#     ╎    ╎     432   @Base/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎ 432   @Base/broadcast.jl:961; macro expansion
#     ╎    ╎    ╎  176   ...e/broadcast.jl:597; getindex
#     ╎    ╎    ╎   95    ...e/broadcast.jl:642; _broadcast_getindex
#     ╎    ╎    ╎    95    .../broadcast.jl:666; _getindex
#     ╎    ╎    ╎     95    .../broadcast.jl:666; _getindex
#     ╎    ╎    ╎    ╎ 95    .../broadcast.jl:636; _broadcast_getindex
#     ╎    ╎    ╎    ╎  95    ...mensional.jl:672; getindex
#   95╎    ╎    ╎    ╎   95    @Base/array.jl:925; getindex
#     ╎    ╎    ╎   81    ...e/broadcast.jl:643; _broadcast_getindex
#     ╎    ╎    ╎    81    .../broadcast.jl:670; _broadcast_getindex_evalf
#     ╎    ╎    ╎     81    ...e/intfuncs.jl:321; literal_pow
#   81╎    ╎    ╎    ╎ 81    @Base/float.jl:385; *
#     ╎    ╎    ╎  256   ...dimensional.jl:674; setindex!
#  256╎    ╎    ╎   256   @Base/array.jl:968; setindex!
#     ╎    ╎     7     @Base/simdloop.jl:78; macro expansion
#    7╎    ╎    ╎ 7     @Base/int.jl:87; +
#    3╎    ╎     4     @Base/simdloop.jl:84; macro expansion
#     ╎    ╎    ╎ 1     ...idimensional.jl:404; iterate
#    1╎    ╎    ╎  1     ...dimensional.jl:423; __inc
#     ╎    ╎   62    @Base/broadcast.jl:211; similar
#     ╎    ╎    62    @Base/broadcast.jl:212; similar
#     ╎    ╎     62    ...bstractarray.jl:840; similar
#     ╎    ╎    ╎ 62    ...bstractarray.jl:841; similar
#     ╎    ╎    ╎  62    @Base/boot.jl:476; Array
#     ╎    ╎    ╎   62    @Base/boot.jl:469; Array
#   62╎    ╎    ╎    62    @Base/boot.jl:461; Array
#     ╎    ╎ 115   @Base/reducedim.jl:406; reduce##kw
#     ╎    ╎  115   @Base/reducedim.jl:406; #reduce#767
#     ╎    ╎   115   @Base/reducedim.jl:357; mapreduce##kw
#     ╎    ╎    115   @Base/reducedim.jl:357; #mapreduce#765
#     ╎    ╎     115   @Base/reducedim.jl:371; _mapreduce_dim
#     ╎    ╎    ╎ 100   @Base/reducedim.jl:324; mapreducedim!
#     ╎    ╎    ╎  99    ...e/reducedim.jl:295; _mapreducedim!(f::typeo...
#    1╎    ╎    ╎   1     @Base/array.jl:924; getindex
#     ╎    ╎    ╎   98    @Base/reduce.jl:272; mapreduce_impl
#     ╎    ╎    ╎    1     @Base/reduce.jl:250; mapreduce_impl(f::type...
#    1╎    ╎    ╎     1     .../promotion.jl:477; ==
#     ╎    ╎    ╎    1     @Base/reduce.jl:255; mapreduce_impl(f::type...
#    1╎    ╎    ╎     1     @Base/array.jl:924; getindex
#     ╎    ╎    ╎    1     @Base/reduce.jl:257; mapreduce_impl(f::type...
#    1╎    ╎    ╎     1     @Base/float.jl:383; +
#     ╎    ╎    ╎    95    @Base/reduce.jl:258; mapreduce_impl(f::type...
#     ╎    ╎    ╎     1     ...e/simdloop.jl:69; macro expansion
#    1╎    ╎    ╎    ╎ 1     @Base/int.jl:87; +
#     ╎    ╎    ╎     1     ...e/simdloop.jl:72; macro expansion
#    1╎    ╎    ╎    ╎ 1     @Base/int.jl:83; <
#   15╎    ╎    ╎     49    ...e/simdloop.jl:75; macro expansion
#   34╎    ╎    ╎    ╎ 34    @Base/int.jl:83; <
#     ╎    ╎    ╎     34    ...e/simdloop.jl:77; macro expansion
#     ╎    ╎    ╎    ╎ 34    @Base/reduce.jl:260; macro expansion
#   34╎    ╎    ╎    ╎  34    @Base/float.jl:383; +
#     ╎    ╎    ╎     10    ...e/simdloop.jl:78; macro expansion
#   10╎    ╎    ╎    ╎ 10    @Base/int.jl:87; +
#     ╎    ╎    ╎  1     ...e/reducedim.jl:297; _mapreducedim!(f::typeo...
#     ╎    ╎    ╎   1     @Base/range.jl:883; iterate
#    1╎    ╎    ╎    1     .../promotion.jl:477; ==
#     ╎    ╎    ╎ 15    @Base/reducedim.jl:219; reducedim_init
#     ╎    ╎    ╎  15    @Base/reducedim.jl:92; reducedim_initarray
#     ╎    ╎    ╎   15    ...e/reducedim.jl:91; reducedim_initarray(A::...
#     ╎    ╎    ╎    9     ...tractarray.jl:803; similar
#     ╎    ╎    ╎     9     @Base/array.jl:378; similar
#     ╎    ╎    ╎    ╎ 9     @Base/boot.jl:469; Array
#    9╎    ╎    ╎    ╎  9     @Base/boot.jl:461; Array
#     ╎    ╎    ╎    6     @Base/array.jl:353; fill!
#    6╎    ╎    ╎     6     @Base/array.jl:966; setindex!
# Total snapshots: 11202. Utilization: 42% across all threads and tasks. Use the `groupby` kwarg to break down by thread and/or task
